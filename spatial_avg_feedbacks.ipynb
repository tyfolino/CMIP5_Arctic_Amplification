# %%
# in this script, we will produce spatial average feedbacks
# this saves computation time in future plotting scripts

#by: Ty Janoski
# updated: 06.04.20

# %%
# import statements
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
def spatial_mean(ds,lat_bound=-90):
    """Take the mean over latitude and longitude dimensions,
    while weighting for latitude.

    PARAMETERS
    ----------
    datasets : list of xarray.Dataset
        A list of xarray datasets to return .

    RETURNS
    -------
    filelist : A list of xarray datasets retrieved from server.
    """
    area_of_int = ds.mean(dim='lon').sel(lat = slice(lat_bound, None))
    weights = (np.cos(np.deg2rad(area_of_int['lat']))/
               np.sum(np.cos(np.deg2rad(area_of_int['lat']))))
    return((area_of_int * weights).sum(dim='lat'))

# %%
models = ['ACCESS1-0','ACCESS1-3','CNRM-CM5','IPSL-CM5B-LR', 'GFDL-ESM2G',
         'MIROC-ESM', 'FGOALS-g2','bcc-csm1-1','BNU-ESM','CanESM2','CCSM4',
          'CSIRO-Mk3-6-0','FGOALS-s2','GFDL-CM3','inmcm4',
         'IPSL-CM5A-LR','MIROC5','MPI-ESM-LR','MPI-ESM-P','MRI-CGCM3','NorESM1-M']
for m in models:
    print(m)
    ts = xr.open_dataset('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_dTs.nc',use_cftime=True).load()
    wv = xr.open_dataset('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_wv.nc',use_cftime=True).load()
    planck = xr.open_dataset('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_planck.nc',use_cftime=True).load()
    lapse = xr.open_dataset('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_lapse.nc',use_cftime=True).load()
    alb = xr.open_dataset('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_shell_albedo.nc',use_cftime=True).load()
    cloud = xr.open_dataset('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_cloud.nc',use_cftime=True).load()
    atmos = xr.open_dataarray('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_atmos_conv.nc',use_cftime=True).load().to_dataset(name='atmos_conv')
    
    arc = xr.merge([spatial_mean(i,lat_bound=70) for i in [ts,wv,planck,lapse,alb,cloud,atmos]])
    glb = xr.merge([spatial_mean(i) for i in [ts,wv,planck,lapse,alb,cloud,atmos]])
        
    if m in ['BNU-ESM','CCSM4','CSIRO-Mk3-6-0','GFDL-CM3','MIROC5',
               'MPI-ESM-LR','MPI-ESM-P','MRI-CGCM3','NorESM1-M','ACCESS1-0','ACCESS1-3',
              'CNRM-CM5','FGOALS-g2','MIROC-ESM']:
        ocean = xr.open_dataarray('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_ocean_conv.nc',use_cftime=True).load()
        if(m in ['CCSM4','FGOALS-g2']):
            ocean['time'] = ts.time
        areacello = xr.open_mfdataset('/dx07/tylerj/CMIP5_output/piControl/areacello_fx_'+m+'_*.nc',
                                     combine='by_coords').areacello
        weights_arc = areacello.where(areacello.lat>70) / areacello.where(areacello.lat>70).sum().sum()
        weights_glb = areacello / areacello.sum().sum()
        ocean_arc = (weights_arc * ocean).sum(axis=[0,1]).to_dataset(name='ml_conv')
        ocean_glb = (weights_glb * ocean).sum(axis=[0,1]).to_dataset(name='ml_conv')
        arc = xr.merge([arc,ocean_arc])
        glb = xr.merge([glb,ocean_glb])
    
    print(arc)
    print(glb)
    
    arc.to_netcdf('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_shell_arc_feedbacks.nc')
    glb.to_netcdf('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_shell_glb_feedbacks.nc')
# Out:
# ACCESS1-0
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0300-01-16 12:00:00 ... 0449-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -2.148 1.832 -0.6739 ... 15.69 20.42 24.31
#     wv_LWAS      (time) float64 -0.6372 -0.1257 -0.4374 ... 3.474 1.874 0.889
#     wv_LWCS      (time) float64 -0.7117 -0.2108 -0.5215 ... 4.33 2.348 1.067
#     wv_SWAS      (time) float64 -0.0002106 0.0004562 -0.0157 ... 0.01522 0.0
#     wv_SWCS      (time) float64 -0.0002578 0.00262 -0.01264 ... 0.01877 0.0
#     wv_NETAS     (time) float64 -0.6374 -0.1252 -0.4531 ... 3.894 1.889 0.889
#     wv_NETCS     (time) float64 -0.712 -0.2082 -0.5341 ... 4.782 2.367 1.067
#     planck_LWAS  (time) float64 5.176 -4.077 1.764 ... -40.36 -49.64 -57.18
#     lapse_LWAS   (time) float64 -0.8058 0.6242 -2.019 ... 15.38 20.25 23.04
#     albedo_SWAS  (time) float64 -0.000141 -0.01874 -0.2054 ... 1.716 0.03036 0.0
#     albedo_SWCS  (time) float64 -0.0004029 -0.08106 -0.6891 ... 0.07107 0.0
#     cloud_LW     (time) float64 -1.204 -1.246 -2.285 ... 7.289 9.793 12.99
#     cloud_SW     (time) float64 0.001251 0.06736 0.6714 ... -1.271 -0.02671 0.0
#     cloud_NET    (time) float64 -1.203 -1.179 -1.613 0.494 ... 6.018 9.767 12.99
#     atmos_conv   (time) float64 11.03 14.02 7.314 ... -20.13 -29.35 -20.68
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0300-01-16 12:00:00 ... 0449-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.1222 0.4222 0.4487 ... 5.487 5.574 5.842
#     wv_LWAS      (time) float64 -0.6571 -0.4868 -0.2947 ... 7.597 7.55 7.537
#     wv_LWCS      (time) float64 -0.8523 -0.6336 -0.2906 ... 10.28 10.14 10.07
#     wv_SWAS      (time) float64 -0.05751 -0.04366 0.008126 ... 1.451 1.431 1.389
#     wv_SWCS      (time) float64 -0.01523 0.0004341 0.03478 ... 0.7411 0.7217
#     wv_NETAS     (time) float64 -0.7146 -0.5305 -0.2865 ... 9.048 8.981 8.925
#     wv_NETCS     (time) float64 -0.8675 -0.6332 -0.2558 ... 11.05 10.89 10.79
#     planck_LWAS  (time) float64 -0.3603 -1.197 -1.437 ... -17.63 -17.48 -17.9
#     lapse_LWAS   (time) float64 0.3008 0.03969 -0.1292 ... -3.311 -3.425 -3.002
#     albedo_SWAS  (time) float64 -0.1975 0.08106 0.1817 ... 1.35 1.985 1.607
#     albedo_SWCS  (time) float64 -0.3051 0.1914 0.3323 ... 3.075 4.014 3.123
#     cloud_LW     (time) float64 0.2117 -0.3471 0.1134 ... 2.128 2.531 2.929
#     cloud_SW     (time) float64 0.9953 1.323 0.2761 ... 2.087 0.4105 0.4965
#     cloud_NET    (time) float64 1.207 0.9763 0.3895 0.5812 ... 4.215 2.941 3.426
#     atmos_conv   (time) float64 -0.7971 0.129 -1.894 ... -0.7211 1.003 -0.153
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# ACCESS1-3
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0250-01-16 12:00:00 ... 0399-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 1.897 1.542 1.957 2.531 ... 14.68 19.01 22.05
#     wv_LWAS      (time) float64 0.03589 -0.1023 0.007198 ... 3.636 2.035 0.6172
#     wv_LWCS      (time) float64 0.06707 -0.1372 0.01935 ... 4.561 2.49 0.7676
#     wv_SWAS      (time) float64 3.93e-05 -0.002863 0.06731 ... 0.01455 0.0
#     wv_SWCS      (time) float64 3.309e-05 -0.001554 0.07437 ... 0.01756 0.0
#     wv_NETAS     (time) float64 0.03593 -0.1051 0.07451 ... 4.028 2.05 0.6172
#     wv_NETCS     (time) float64 0.0671 -0.1388 0.09372 ... 4.981 2.507 0.7676
#     planck_LWAS  (time) float64 -4.543 -3.633 -4.69 ... -38.05 -46.23 -51.85
#     lapse_LWAS   (time) float64 1.154 1.836 1.832 1.944 ... 11.87 16.74 21.12
#     albedo_SWAS  (time) float64 4.82e-05 0.02347 0.2442 ... 1.548 0.03411 0.0
#     albedo_SWCS  (time) float64 0.000145 0.06863 0.6817 ... 3.527 0.07882 0.0
#     cloud_LW     (time) float64 0.5456 -0.2874 1.069 1.887 ... 6.543 5.151 6.814
#     cloud_SW     (time) float64 0.001156 0.02246 -0.2816 ... -0.03318 0.0
#     cloud_NET    (time) float64 0.5468 -0.265 0.7871 0.8856 ... 5.72 5.118 6.814
#     atmos_conv   (time) float64 13.81 -9.189 -4.419 1.768 ... 6.563 -12.88 -35.8
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0250-01-16 12:00:00 ... 0399-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.2138 0.2995 0.3151 ... 5.002 5.145 5.234
#     wv_LWAS      (time) float64 -0.5945 -0.5394 -0.4205 ... 7.016 6.281 6.44
#     wv_LWCS      (time) float64 -0.772 -0.7352 -0.5089 ... 9.43 8.528 8.62
#     wv_SWAS      (time) float64 -0.06095 -0.06148 -0.006641 ... 1.238 1.277
#     wv_SWCS      (time) float64 -0.01948 0.008687 0.01838 ... 0.6549 0.679
#     wv_NETAS     (time) float64 -0.6554 -0.6008 -0.4271 ... 8.315 7.519 7.717
#     wv_NETCS     (time) float64 -0.7915 -0.7266 -0.4905 ... 10.11 9.182 9.299
#     planck_LWAS  (time) float64 -0.5425 -0.8585 -0.8878 ... -16.21 -16.17 -16.09
#     lapse_LWAS   (time) float64 0.5084 0.15 0.2284 ... -3.148 -2.934 -2.52
#     albedo_SWAS  (time) float64 -0.0003525 0.05075 0.1359 ... 1.057 1.611 1.602
#     albedo_SWCS  (time) float64 0.02127 0.1419 0.317 ... 2.547 3.422 3.388
#     cloud_LW     (time) float64 -0.08739 -0.2351 0.1493 ... 0.6958 0.4644 0.9254
#     cloud_SW     (time) float64 0.6516 0.02113 0.2927 ... 2.784 2.647 2.084
#     cloud_NET    (time) float64 0.5642 -0.2139 0.4419 ... 3.48 3.111 3.009
#     atmos_conv   (time) float64 -0.0286 -1.422 0.2214 ... 1.142 1.162 3.224
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# CNRM-CM5
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 4.526 -0.0243 3.119 3.287 ... 16.09 21.78 24.99
#     wv_LWAS      (time) float64 -0.403 0.305 0.6119 ... 4.155 1.809 0.9206
#     wv_LWCS      (time) float64 -0.3111 0.5538 0.6623 ... 5.21 2.329 1.171
#     wv_SWAS      (time) float64 5.678e-05 -0.01141 0.2454 ... 0.4347 0.01336 0.0
#     wv_SWCS      (time) float64 8.074e-05 -0.01199 0.276 ... 0.4744 0.01687 0.0
#     wv_NETAS     (time) float64 -0.4029 0.2936 0.8573 ... 4.59 1.822 0.9206
#     wv_NETCS     (time) float64 -0.311 0.5418 0.9383 1.707 ... 5.684 2.346 1.171
#     planck_LWAS  (time) float64 -10.86 -0.2521 -7.605 ... -41.88 -53.34 -59.51
#     lapse_LWAS   (time) float64 5.49 1.591 1.171 1.914 ... 12.76 21.88 23.23
#     albedo_SWAS  (time) float64 -1.875e-05 0.008934 0.3054 ... 1.744 0.03937 0.0
#     albedo_SWCS  (time) float64 0.0001691 0.107 1.167 ... 4.359 0.08724 0.0
#     cloud_LW     (time) float64 -0.3505 0.5106 0.2662 0.3905 ... 6.04 6.482 7.41
#     cloud_SW     (time) float64 -0.002722 -0.005295 0.135 ... -0.03322 0.0
#     cloud_NET    (time) float64 -0.3533 0.5053 0.4012 ... 5.126 6.449 7.41
#     atmos_conv   (time) float64 -2.092 -3.901 -1.449 ... 5.421 -7.63 -21.33
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.4337 0.5211 0.7599 ... 5.247 5.351 5.507
#     wv_LWAS      (time) float64 -0.4146 0.3716 0.6988 ... 6.894 7.009 6.502
#     wv_LWCS      (time) float64 -0.4965 0.4375 0.8339 ... 9.342 9.322 8.71
#     wv_SWAS      (time) float64 -0.08408 0.01298 0.1251 ... 1.365 1.41 1.335
#     wv_SWCS      (time) float64 -0.03913 0.02291 0.1133 ... 0.7656 0.7813 0.7154
#     wv_NETAS     (time) float64 -0.4987 0.3845 0.8239 ... 8.259 8.419 7.837
#     wv_NETCS     (time) float64 -0.5356 0.4604 0.9472 ... 10.11 10.1 9.425
#     planck_LWAS  (time) float64 -1.18 -1.693 -2.37 ... -16.84 -16.84 -17.03
#     lapse_LWAS   (time) float64 0.2608 -0.5909 -0.6964 ... -2.292 -2.484 -2.579
#     albedo_SWAS  (time) float64 -0.03831 0.1115 0.1039 ... 2.245 2.645 1.325
#     albedo_SWCS  (time) float64 -0.0717 0.2299 0.2839 ... 4.494 4.88 2.388
#     cloud_LW     (time) float64 -0.4024 -0.335 0.179 ... 2.055 2.258 1.396
#     cloud_SW     (time) float64 1.965 1.6 1.882 2.081 ... 0.4757 -0.4468 0.879
#     cloud_NET    (time) float64 1.563 1.265 2.061 1.502 ... 2.532 1.811 2.275
#     atmos_conv   (time) float64 -0.2355 -0.4943 -1.173 ... -0.6079 -1.166
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# IPSL-CM5B-LR
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 3.564 1.196 0.4558 -0.1559 ... 20.21 24.47 21.11
#     wv_LWAS      (time) float64 0.327 0.1819 -0.6906 ... 3.542 1.464 1.046
#     wv_LWCS      (time) float64 0.2458 0.1554 -0.9132 ... 4.533 1.925 1.317
#     wv_SWAS      (time) float64 0.0002043 0.0006486 -0.1152 ... 0.00932 0.0
#     wv_SWCS      (time) float64 0.0003024 -0.001559 -0.1362 ... 0.01186 0.0
#     wv_NETAS     (time) float64 0.3273 0.1825 -0.8058 ... 3.958 1.473 1.046
#     wv_NETCS     (time) float64 0.2461 0.1539 -1.049 0.167 ... 5.0 1.937 1.317
#     planck_LWAS  (time) float64 -8.432 -2.819 -0.9488 ... -52.72 -60.58 -50.78
#     lapse_LWAS   (time) float64 0.93 2.735 2.332 -0.5748 ... 23.32 30.22 22.56
#     albedo_SWAS  (time) float64 0.0 -0.04084 -0.1509 ... 1.934 0.03293 0.0
#     albedo_SWCS  (time) float64 0.0 -0.05584 -0.286 ... 5.008 0.09954 0.0
#     cloud_LW     (time) float64 -0.004586 0.1509 0.4299 ... 8.816 4.815 3.678
#     cloud_SW     (time) float64 4.532e-05 -0.09753 -0.2269 ... -0.07392 0.0
#     cloud_NET    (time) float64 -0.004541 0.05335 0.203 ... 6.166 4.741 3.678
#     atmos_conv   (time) float64 -25.91 -21.54 -1.94 -2.103 ... 17.8 -5.47 -23.92
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.04795 0.4144 0.4611 ... 4.279 4.249 4.381
#     wv_LWAS      (time) float64 -0.4927 0.1655 0.5091 ... 5.486 5.052 5.107
#     wv_LWCS      (time) float64 -0.7369 0.1357 0.739 1.074 ... 7.468 6.95 7.084
#     wv_SWAS      (time) float64 -0.1197 0.02547 0.08571 ... 0.9948 0.9688 0.9739
#     wv_SWCS      (time) float64 -0.06085 0.04819 0.03231 ... 0.4704 0.498 0.4568
#     wv_NETAS     (time) float64 -0.6124 0.191 0.5948 ... 6.481 6.021 6.081
#     wv_NETCS     (time) float64 -0.7977 0.1839 0.7713 1.13 ... 7.939 7.448 7.541
#     planck_LWAS  (time) float64 -0.1486 -1.256 -1.383 ... -13.48 -13.11 -13.32
#     lapse_LWAS   (time) float64 0.2333 -0.142 -0.2578 ... -1.691 -1.183 -1.46
#     albedo_SWAS  (time) float64 0.0535 0.1791 0.243 ... 0.7128 0.5745 0.3758
#     albedo_SWCS  (time) float64 0.03717 0.2536 0.3757 ... 1.333 1.049 0.6871
#     cloud_LW     (time) float64 -0.2846 -0.5315 0.527 ... -0.02923 0.192 0.5884
#     cloud_SW     (time) float64 2.041 1.151 0.9253 1.624 ... 2.523 3.143 1.704
#     cloud_NET    (time) float64 1.757 0.6195 1.452 1.238 ... 2.492 3.335 2.293
#     atmos_conv   (time) float64 -1.854 -0.792 -0.07718 ... 2.314 -0.1104 -1.693
# GFDL-ESM2G
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -3.123 1.088 4.277 0.8073 ... 14.54 18.43 17.29
#     wv_LWAS      (time) float64 0.0665 0.5397 0.8536 ... 3.101 2.098 1.442
#     wv_LWCS      (time) float64 0.1292 0.6226 0.797 0.6392 ... 3.792 2.609 1.655
#     wv_SWAS      (time) float64 -0.0001884 0.0188 0.4812 ... 0.3804 0.01368 0.0
#     wv_SWCS      (time) float64 -0.0002713 0.01817 0.56 ... 0.4102 0.01661 0.0
#     wv_NETAS     (time) float64 0.06632 0.5585 1.335 ... 3.481 2.111 1.442
#     wv_NETCS     (time) float64 0.1289 0.6407 1.357 1.023 ... 4.202 2.626 1.655
#     planck_LWAS  (time) float64 7.453 -2.341 -10.16 ... -37.31 -44.97 -40.51
#     lapse_LWAS   (time) float64 -1.488 -1.044 1.589 -1.606 ... 14.54 19.11 14.46
#     albedo_SWAS  (time) float64 4.084e-05 0.02581 0.09529 ... 1.724 0.03414 0.0
#     albedo_SWCS  (time) float64 -1.626e-05 0.002877 -0.06191 ... 0.09199 0.0
#     cloud_LW     (time) float64 0.6679 0.5871 0.5184 ... 5.319 6.234 5.499
#     cloud_SW     (time) float64 -0.0003442 -0.01912 -0.1299 ... -0.002883 0.0
#     cloud_NET    (time) float64 0.6676 0.568 0.3885 ... 4.944 6.231 5.499
#     atmos_conv   (time) float64 15.84 15.46 5.38 ... -11.16 -8.349 -0.2156
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.009739 0.4401 0.7179 ... 3.863 4.029 4.148
#     wv_LWAS      (time) float64 -0.2555 0.1836 0.868 1.0 ... 6.596 6.43 6.419
#     wv_LWCS      (time) float64 -0.2983 0.2253 1.148 1.4 ... 8.787 8.618 8.582
#     wv_SWAS      (time) float64 -0.01719 0.002302 0.1522 ... 1.121 1.103 1.14
#     wv_SWCS      (time) float64 0.005827 0.001447 0.09133 ... 0.5473 0.5666
#     wv_NETAS     (time) float64 -0.2727 0.1859 1.02 1.178 ... 7.717 7.532 7.559
#     wv_NETCS     (time) float64 -0.2925 0.2267 1.239 1.508 ... 9.35 9.165 9.148
#     planck_LWAS  (time) float64 -0.1636 -1.337 -2.133 ... -12.52 -12.7 -12.75
#     lapse_LWAS   (time) float64 0.09721 -0.1542 -0.5752 ... -3.956 -3.54 -3.582
#     albedo_SWAS  (time) float64 0.0956 0.05166 0.01174 ... 0.368 0.5468 0.7765
#     albedo_SWCS  (time) float64 0.1145 0.07588 -0.02025 ... 0.8128 1.033 1.43
#     cloud_LW     (time) float64 0.8023 0.621 0.746 0.5842 ... 2.865 3.206 2.823
#     cloud_SW     (time) float64 1.613 0.9504 0.4893 ... 0.123 -1.424 -2.428
#     cloud_NET    (time) float64 2.415 1.571 1.235 1.269 ... 2.989 1.782 0.3947
#     atmos_conv   (time) float64 2.299 -0.1554 -1.513 ... 1.304 -1.037 -0.1521
# MIROC-ESM
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 1.332 0.2541 1.455 2.411 ... 16.79 20.0 22.01
#     wv_LWAS      (time) float64 -0.2354 -0.2751 -0.3923 ... 4.501 2.884 1.255
#     wv_LWCS      (time) float64 -0.2352 -0.2152 -0.3907 ... 5.609 3.527 1.52
#     wv_SWAS      (time) float64 -8.03e-05 -0.01808 -0.07852 ... 0.01599 0.0
#     wv_SWCS      (time) float64 -0.0001274 -0.01838 -0.09895 ... 0.01882 0.0
#     wv_NETAS     (time) float64 -0.2355 -0.2931 -0.4708 ... 4.986 2.9 1.255
#     wv_NETCS     (time) float64 -0.2353 -0.2335 -0.4896 ... 6.123 3.545 1.52
#     planck_LWAS  (time) float64 -3.094 -0.6404 -3.424 ... -43.19 -48.39 -51.16
#     lapse_LWAS   (time) float64 2.204 1.935 3.509 1.474 ... 12.32 16.37 19.01
#     albedo_SWAS  (time) float64 0.0001082 0.04724 0.328 ... 1.759 0.0435 0.0
#     albedo_SWCS  (time) float64 0.0003131 0.1115 0.7978 ... 4.127 0.08236 0.0
#     cloud_LW     (time) float64 0.8896 1.552 2.413 0.1157 ... 5.97 7.327 7.306
#     cloud_SW     (time) float64 -0.0005218 -0.08472 -0.4728 ... -0.0571 0.0
#     cloud_NET    (time) float64 0.8891 1.468 1.94 0.05877 ... 3.373 7.27 7.306
#     atmos_conv   (time) float64 -19.27 -19.4 -6.844 ... 8.788 -9.139 -21.62
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -0.2059 0.09776 0.2442 ... 6.134 6.26 6.353
#     wv_LWAS      (time) float64 -0.7219 -0.6029 0.06204 ... 9.401 9.221 9.2
#     wv_LWCS      (time) float64 -1.04 -0.8762 0.08561 ... 12.73 12.42 12.24
#     wv_SWAS      (time) float64 -0.1669 -0.118 -0.01622 ... 1.682 1.688 1.776
#     wv_SWCS      (time) float64 -0.07399 -0.05081 -0.009717 ... 0.8716 0.9194
#     wv_NETAS     (time) float64 -0.8888 -0.7209 0.04581 ... 11.08 10.91 10.98
#     wv_NETCS     (time) float64 -1.114 -0.927 0.07589 ... 13.55 13.29 13.16
#     planck_LWAS  (time) float64 0.7407 -0.2521 -0.733 ... -20.0 -19.97 -19.93
#     lapse_LWAS   (time) float64 0.3013 0.2444 -0.3542 ... -5.241 -4.433 -4.826
#     albedo_SWAS  (time) float64 -0.4465 -0.07254 0.1568 ... 1.205 1.844 1.745
#     albedo_SWCS  (time) float64 -0.8637 -0.1712 0.2194 ... 2.697 3.564 3.044
#     cloud_LW     (time) float64 -0.4008 -0.332 0.214 ... 2.772 2.788 3.316
#     cloud_SW     (time) float64 3.782 3.523 2.245 2.739 ... 2.533 1.406 0.6462
#     cloud_NET    (time) float64 3.381 3.191 2.459 2.393 ... 5.304 4.194 3.962
#     atmos_conv   (time) float64 0.711 -1.295 -1.852 ... 0.502 1.03 -0.6019
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# FGOALS-g2
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0490-01-16 12:00:00 ... 0639-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 1.5 1.785 1.071 3.207 ... 9.743 17.0 22.46 25.32
#     wv_LWAS      (time) float64 0.4063 0.3751 0.42 1.08 ... 3.276 1.866 1.046
#     wv_LWCS      (time) float64 0.5055 0.3841 0.5086 1.222 ... 4.081 2.399 1.224
#     wv_SWAS      (time) float64 0.000188 0.02478 0.02563 ... 0.4007 0.01429 0.0
#     wv_SWCS      (time) float64 0.0002469 0.03169 0.006214 ... 0.01702 0.0
#     wv_NETAS     (time) float64 0.4065 0.3999 0.4456 2.212 ... 3.676 1.88 1.046
#     wv_NETCS     (time) float64 0.5058 0.4158 0.5148 2.457 ... 4.51 2.416 1.224
#     planck_LWAS  (time) float64 -3.533 -4.258 -2.665 ... -43.76 -54.87 -59.8
#     lapse_LWAS   (time) float64 1.354 0.4445 1.108 1.46 ... 16.64 23.83 23.62
#     albedo_SWAS  (time) float64 3.273e-05 -0.0039 0.02967 ... 1.825 0.03347 0.0
#     albedo_SWCS  (time) float64 7.618e-05 -0.01714 0.03983 ... 4.622 0.08807 0.0
#     cloud_LW     (time) float64 1.474 -0.6243 -0.2835 ... 5.427 3.143 1.261
#     cloud_SW     (time) float64 -0.000745 0.001993 -0.2523 ... -0.04182 0.0
#     cloud_NET    (time) float64 1.473 -0.6223 -0.5358 ... 3.937 3.102 1.261
#     atmos_conv   (time) float64 -9.429 0.8911 0.2765 ... -0.2563 -16.99 -10.11
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0490-01-16 12:00:00 ... 0639-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.487 0.6989 0.8955 0.9448 ... 5.661 5.824 5.811
#     wv_LWAS      (time) float64 0.4059 0.867 0.8873 1.323 ... 8.352 8.095 8.11
#     wv_LWCS      (time) float64 0.4863 1.026 1.194 1.705 ... 11.13 10.87 10.92
#     wv_SWAS      (time) float64 0.08695 0.1554 0.207 ... 1.503 1.515 1.574
#     wv_SWCS      (time) float64 0.06306 0.09322 0.1264 ... 0.7749 0.8092 0.8259
#     wv_NETAS     (time) float64 0.4928 1.022 1.094 1.576 ... 9.855 9.61 9.684
#     wv_NETCS     (time) float64 0.5494 1.119 1.32 1.871 ... 11.91 11.68 11.75
#     planck_LWAS  (time) float64 -1.491 -2.117 -2.747 ... -18.04 -18.18 -17.83
#     lapse_LWAS   (time) float64 -0.1805 -0.5081 -0.285 ... -2.558 -2.323 -2.948
#     albedo_SWAS  (time) float64 0.1359 0.08424 0.03664 ... 2.111 2.612 2.186
#     albedo_SWCS  (time) float64 0.2765 0.2029 0.1314 ... 4.849 5.644 4.626
#     cloud_LW     (time) float64 1.254 0.6986 1.035 0.8048 ... 3.584 3.591 3.373
#     cloud_SW     (time) float64 -0.7021 -0.5549 -0.6556 ... -1.075 -2.14 -1.798
#     cloud_NET    (time) float64 0.5519 0.1438 0.379 0.1961 ... 2.508 1.451 1.576
#     atmos_conv   (time) float64 0.3895 -0.5794 -1.542 ... 0.04768 0.4605 1.451
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# bcc-csm1-1
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0160-01-16 12:00:00 ... 0309-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -2.669 1.702 3.262 2.875 ... 15.62 22.49 22.4
#     wv_LWAS      (time) float64 -0.9381 0.2262 0.101 ... 2.857 1.752 1.115
#     wv_LWCS      (time) float64 -1.345 0.2864 -0.0866 0.147 ... 3.659 2.36 1.406
#     wv_SWAS      (time) float64 -0.0003523 -0.005662 0.1999 ... 0.01329 0.0
#     wv_SWCS      (time) float64 -0.0004278 -0.008724 0.2326 ... 0.01668 0.0
#     wv_NETAS     (time) float64 -0.9384 0.2205 0.3009 ... 3.231 1.765 1.115
#     wv_NETCS     (time) float64 -1.345 0.2776 0.146 1.01 ... 4.072 2.377 1.406
#     planck_LWAS  (time) float64 6.366 -3.869 -7.524 ... -40.18 -54.57 -53.16
#     lapse_LWAS   (time) float64 0.1635 1.572 2.927 2.665 ... 15.44 23.71 21.52
#     albedo_SWAS  (time) float64 -0.0001029 -0.02843 -0.1126 ... 0.03309 0.0
#     albedo_SWCS  (time) float64 -0.0002007 -0.05736 -0.2872 ... 0.08827 0.0
#     cloud_LW     (time) float64 0.9438 3.639 3.673 2.957 ... 8.406 15.04 7.809
#     cloud_SW     (time) float64 -0.001225 -0.0586 ... -0.08152 -0.0009595
#     cloud_NET    (time) float64 0.9425 3.58 3.099 0.2765 ... 6.039 14.96 7.808
#     atmos_conv   (time) float64 -27.74 -5.641 -4.465 ... -14.75 -6.784 36.93
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0160-01-16 12:00:00 ... 0309-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.1055 0.3372 0.5507 0.7034 ... 4.964 5.107 5.34
#     wv_LWAS      (time) float64 -0.1428 -0.01101 0.2355 ... 6.456 6.338 6.114
#     wv_LWCS      (time) float64 -0.07019 0.06514 0.2719 ... 8.747 8.589 8.426
#     wv_SWAS      (time) float64 -0.008634 0.01034 0.05707 ... 1.223 1.229 1.27
#     wv_SWCS      (time) float64 -0.007798 -0.0007953 0.03239 ... 0.6388 0.6675
#     wv_NETAS     (time) float64 -0.1515 -0.0006703 0.2925 ... 7.679 7.567 7.383
#     wv_NETCS     (time) float64 -0.07799 0.06435 0.3043 ... 9.366 9.228 9.093
#     planck_LWAS  (time) float64 -0.3001 -0.999 -1.584 ... -15.85 -15.88 -16.26
#     lapse_LWAS   (time) float64 -0.5007 -0.4881 -0.2024 ... -1.959 -1.824 -1.793
#     albedo_SWAS  (time) float64 0.05557 0.1516 0.1732 ... 1.48 1.866 1.735
#     albedo_SWCS  (time) float64 0.1018 0.2962 0.3416 ... 3.458 4.061 3.497
#     cloud_LW     (time) float64 0.4569 0.06976 0.1776 ... 1.699 2.313 2.87
#     cloud_SW     (time) float64 -0.04321 0.4492 1.243 ... 0.8984 -0.5463 -1.565
#     cloud_NET    (time) float64 0.4137 0.5189 1.42 1.079 ... 2.597 1.767 1.305
#     atmos_conv   (time) float64 -1.119 0.8061 -0.8191 ... 0.7047 0.6014 -1.18
# BNU-ESM
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 4.496 2.171 2.181 3.424 ... 19.27 24.27 26.05
#     wv_LWAS      (time) float64 -0.1554 0.3145 -0.07072 ... 3.822 2.387 1.137
#     wv_LWCS      (time) float64 -0.1329 0.3539 -0.1148 ... 4.75 2.921 1.393
#     wv_SWAS      (time) float64 0.0001776 0.02071 0.07521 ... 0.4275 0.01637 0.0
#     wv_SWCS      (time) float64 0.0002565 0.02522 0.08678 ... 0.4614 0.0195 0.0
#     wv_NETAS     (time) float64 -0.1553 0.3352 0.004489 ... 4.249 2.404 1.137
#     wv_NETCS     (time) float64 -0.1326 0.3792 -0.028 1.782 ... 5.211 2.94 1.393
#     planck_LWAS  (time) float64 -10.76 -5.042 -5.13 ... -49.52 -58.65 -60.6
#     lapse_LWAS   (time) float64 2.536 2.096 2.487 2.499 ... 19.42 25.14 25.32
#     albedo_SWAS  (time) float64 2.856e-06 -0.01986 -0.03055 ... 0.05071 0.0
#     albedo_SWCS  (time) float64 5.744e-05 -0.009164 -0.03604 ... 0.1197 0.0
#     cloud_LW     (time) float64 -1.934 1.942 1.671 3.036 ... 10.71 10.73 11.23
#     cloud_SW     (time) float64 0.0002343 -0.06655 -0.3227 ... -0.09837 0.0
#     cloud_NET    (time) float64 -1.933 1.876 1.349 1.267 ... 7.4 10.63 11.23
#     atmos_conv   (time) float64 -5.815 -15.93 -10.09 ... -16.6 -20.32 4.867
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.3539 0.253 0.5222 0.6183 ... 5.9 6.163 6.187
#     wv_LWAS      (time) float64 -0.7204 -0.3729 -0.1228 ... 7.897 7.38 7.178
#     wv_LWCS      (time) float64 -0.6934 -0.4266 -0.05577 ... 10.6 9.939 9.724
#     wv_SWAS      (time) float64 -0.06918 -0.007269 0.04181 ... 1.517 1.511 1.454
#     wv_SWCS      (time) float64 -0.05123 0.004806 0.02545 ... 0.8695 0.7912
#     wv_NETAS     (time) float64 -0.7896 -0.3801 -0.08097 ... 9.414 8.891 8.632
#     wv_NETCS     (time) float64 -0.7447 -0.4218 -0.03032 ... 11.43 10.81 10.52
#     planck_LWAS  (time) float64 -0.8414 -0.7336 -1.51 ... -18.71 -18.96 -18.69
#     lapse_LWAS   (time) float64 0.1793 -0.2916 0.3014 ... -2.281 -1.99 -1.78
#     albedo_SWAS  (time) float64 0.04468 0.2407 0.439 ... 2.713 3.529 3.619
#     albedo_SWCS  (time) float64 0.09046 0.3105 0.7277 1.404 ... 6.389 7.972 7.69
#     cloud_LW     (time) float64 -0.1558 -0.6788 -0.009741 ... 2.695 2.394 2.605
#     cloud_SW     (time) float64 0.5151 0.4085 1.187 ... -0.329 -0.7907 -1.222
#     cloud_NET    (time) float64 0.3592 -0.2703 1.177 1.144 ... 2.365 1.603 1.383
#     atmos_conv   (time) float64 1.279 2.434 -2.877 0.464 ... 1.835 2.431 0.4652
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# CanESM2
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.0762 -3.639 -0.1898 ... 14.33 21.18 24.08
#     wv_LWAS      (time) float64 0.05398 0.1677 -0.0295 ... 4.238 2.852 1.636
#     wv_LWCS      (time) float64 0.1708 0.3285 -0.07373 ... 5.333 3.395 1.924
#     wv_SWAS      (time) float64 -5.35e-05 -0.04407 -0.1299 ... 0.01769 0.0
#     wv_SWCS      (time) float64 -3.946e-05 -0.05921 -0.1672 ... 0.0213 0.0
#     wv_NETAS     (time) float64 0.05393 0.1236 -0.1594 ... 4.687 2.87 1.636
#     wv_NETCS     (time) float64 0.1707 0.2693 -0.2409 ... 5.803 3.417 1.924
#     planck_LWAS  (time) float64 -0.1488 8.52 0.452 ... -36.71 -51.49 -56.72
#     lapse_LWAS   (time) float64 -0.9626 -2.565 0.5318 0.699 ... 9.93 18.57 21.43
#     albedo_SWAS  (time) float64 -8.32e-05 -0.02769 -0.0811 ... 1.192 0.0273 0.0
#     albedo_SWCS  (time) float64 -0.0003218 -0.09265 -0.245 ... 2.766 0.06012 0.0
#     cloud_LW     (time) float64 0.2526 0.2378 1.106 0.5492 ... 10.29 7.945 8.15
#     cloud_SW     (time) float64 0.0006023 -0.116 ... -0.07583 -8.204e-06
#     cloud_NET    (time) float64 0.2532 0.1218 1.085 1.062 ... 7.511 7.87 8.15
#     atmos_conv   (time) float64 12.59 -9.599 -10.55 ... 12.32 -3.638 -38.42
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.3352 0.3606 0.5261 0.817 ... 5.947 6.102 6.295
#     wv_LWAS      (time) float64 -0.4533 -0.2854 0.07225 ... 8.811 8.079 8.17
#     wv_LWCS      (time) float64 -0.6719 -0.3167 0.2759 ... 11.79 10.84 10.84
#     wv_SWAS      (time) float64 -0.03295 -0.008315 0.03767 ... 1.696 1.534 1.566
#     wv_SWCS      (time) float64 0.02292 -0.003872 0.005076 ... 0.782 0.8094
#     wv_NETAS     (time) float64 -0.4863 -0.2938 0.1099 ... 10.51 9.614 9.735
#     wv_NETCS     (time) float64 -0.649 -0.3206 0.2809 ... 12.7 11.63 11.65
#     planck_LWAS  (time) float64 -1.12 -1.306 -1.738 ... -19.21 -19.29 -19.57
#     lapse_LWAS   (time) float64 0.2572 -0.7358 -0.8477 ... -3.796 -3.569 -3.435
#     albedo_SWAS  (time) float64 0.3737 0.1672 -0.0453 ... 1.379 1.878 1.85
#     albedo_SWCS  (time) float64 0.7748 0.4266 0.05592 0.31 ... 3.406 4.215 3.904
#     cloud_LW     (time) float64 -0.1877 -0.09651 -0.07465 ... 5.407 4.918 4.943
#     cloud_SW     (time) float64 2.368 2.439 2.439 ... -0.6632 -0.1905 0.1832
#     cloud_NET    (time) float64 2.18 2.343 2.364 1.49 ... 4.744 4.728 5.126
#     atmos_conv   (time) float64 -1.146 0.06405 -0.7984 ... -0.7704 0.7795 -1.408
# CCSM4
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 2.048 -0.869 2.194 1.582 ... 16.21 22.27 21.74
#     wv_LWAS      (time) float64 0.03627 -0.27 0.1348 ... 3.062 2.357 1.157
#     wv_LWCS      (time) float64 0.05164 -0.3591 0.1699 ... 3.73 2.799 1.313
#     wv_SWAS      (time) float64 0.0001579 -0.01509 0.2025 ... 0.3069 0.01424 0.0
#     wv_SWCS      (time) float64 0.0002222 -0.01867 0.2202 ... 0.3268 0.01684 0.0
#     wv_NETAS     (time) float64 0.03643 -0.2851 0.3373 ... 3.369 2.372 1.157
#     wv_NETCS     (time) float64 0.05186 -0.3777 0.3901 ... 4.056 2.816 1.313
#     planck_LWAS  (time) float64 -4.724 2.017 -5.194 ... -41.46 -53.67 -50.34
#     lapse_LWAS   (time) float64 1.501 0.4627 1.9 1.332 ... 16.41 22.55 21.36
#     albedo_SWAS  (time) float64 8.655e-05 0.005999 0.1288 ... 2.04 0.04001 0.0
#     albedo_SWCS  (time) float64 0.0002133 0.01715 0.2065 ... 5.038 0.09436 0.0
#     cloud_LW     (time) float64 -0.6696 -0.5704 0.3561 ... 5.582 6.79 6.937
#     cloud_SW     (time) float64 0.0003263 0.003441 -0.0176 ... -0.04277 0.0
#     cloud_NET    (time) float64 -0.6693 -0.567 0.3385 ... 3.665 6.748 6.937
#     atmos_conv   (time) float64 -23.84 -19.2 -0.181 ... -3.565 -11.25 -18.01
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.7947 0.8417 0.9652 ... 5.011 5.197 5.315
#     wv_LWAS      (time) float64 0.1219 0.5523 0.3474 0.67 ... 6.494 6.135 5.715
#     wv_LWCS      (time) float64 0.1614 0.7595 0.5404 1.013 ... 8.682 8.231 7.794
#     wv_SWAS      (time) float64 0.04362 0.1762 0.1671 ... 1.237 1.277 1.255
#     wv_SWCS      (time) float64 0.02591 0.1231 0.1178 ... 0.6263 0.7195 0.6839
#     wv_NETAS     (time) float64 0.1655 0.7286 0.5145 0.815 ... 7.731 7.412 6.97
#     wv_NETCS     (time) float64 0.1873 0.8826 0.6583 1.091 ... 9.308 8.95 8.477
#     planck_LWAS  (time) float64 -2.358 -2.596 -2.952 ... -15.94 -16.11 -16.23
#     lapse_LWAS   (time) float64 0.3677 -0.4735 -0.09891 ... -1.796 -1.534 -1.4
#     albedo_SWAS  (time) float64 0.2314 0.2732 0.2239 0.2218 ... 1.562 1.95 2.295
#     albedo_SWCS  (time) float64 0.4902 0.6387 0.5958 ... 4.001 4.797 5.355
#     cloud_LW     (time) float64 0.3906 0.7105 -0.6488 ... 2.689 2.623 2.418
#     cloud_SW     (time) float64 2.218 0.8985 2.186 ... 0.6804 -0.6727 0.01332
#     cloud_NET    (time) float64 2.608 1.609 1.537 2.233 ... 3.37 1.95 2.432
#     atmos_conv   (time) float64 0.6874 -2.519 3.078 ... -1.924 0.619 -1.411
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# CSIRO-Mk3-6-0
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 1.535 -1.126 0.2618 2.208 ... 17.0 19.1 18.62
#     wv_LWAS      (time) float64 -0.2149 -0.3986 0.1061 ... 4.377 2.527 1.724
#     wv_LWCS      (time) float64 -0.239 -0.5876 0.1502 ... 5.305 3.194 2.096
#     wv_SWAS      (time) float64 -2.35e-05 -0.04073 0.08708 ... 0.01405 0.0
#     wv_SWCS      (time) float64 -1.821e-05 -0.05558 0.06731 ... 0.01694 0.0
#     wv_NETAS     (time) float64 -0.2149 -0.4394 0.1932 ... 4.807 2.541 1.724
#     wv_NETCS     (time) float64 -0.239 -0.6432 0.2175 ... 5.772 3.211 2.096
#     planck_LWAS  (time) float64 -3.692 2.834 -0.5875 ... -44.47 -47.16 -44.64
#     lapse_LWAS   (time) float64 1.079 -0.9359 -1.027 1.914 ... 17.02 19.85 15.94
#     albedo_SWAS  (time) float64 3.102e-05 0.00556 0.04856 ... 1.934 0.03991 0.0
#     albedo_SWCS  (time) float64 8.827e-05 -0.005488 -0.001719 ... 0.1085 0.0
#     cloud_LW     (time) float64 0.01687 -0.6966 0.3034 ... 4.909 6.719 4.57
#     cloud_SW     (time) float64 0.001028 0.02527 -0.03666 ... -0.01639 0.0
#     cloud_NET    (time) float64 0.0179 -0.6713 0.2667 ... 3.979 6.703 4.57
#     atmos_conv   (time) float64 2.496 -1.392 -0.4177 ... -4.444 -13.58 20.82
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.1223 0.2713 0.3859 ... 5.903 5.943 6.099
#     wv_LWAS      (time) float64 -0.5146 -0.4193 -0.06094 ... 8.305 8.024 7.964
#     wv_LWCS      (time) float64 -0.7874 -0.481 -0.02233 ... 11.19 10.75 10.68
#     wv_SWAS      (time) float64 -0.07901 -0.04116 0.0314 ... 1.499 1.458 1.526
#     wv_SWCS      (time) float64 -0.0248 -0.0189 0.03273 ... 0.7382 0.7252 0.7764
#     wv_NETAS     (time) float64 -0.5936 -0.4604 -0.02954 ... 9.803 9.482 9.491
#     wv_NETCS     (time) float64 -0.8122 -0.4999 0.01041 ... 11.93 11.47 11.46
#     planck_LWAS  (time) float64 -0.3636 -0.8616 -1.186 ... -19.13 -18.94 -19.23
#     lapse_LWAS   (time) float64 0.5309 -0.1534 0.09061 ... -3.891 -3.483 -3.099
#     albedo_SWAS  (time) float64 -0.1935 -0.09676 0.01717 ... 1.823 2.463 2.365
#     albedo_SWCS  (time) float64 -0.438 -0.2774 -0.0101 ... 4.074 5.262 5.29
#     cloud_LW     (time) float64 -0.01598 -0.6599 -0.09139 ... 0.9478 1.002
#     cloud_SW     (time) float64 2.098 1.5 1.265 0.5248 ... 3.229 2.286 1.466
#     cloud_NET    (time) float64 2.082 0.8405 1.173 0.8759 ... 3.995 3.234 2.468
#     atmos_conv   (time) float64 -1.023 0.4128 -1.358 ... 1.856 0.1282 0.7427
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# FGOALS-s2
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 3.674 3.584 1.75 3.012 ... 21.16 26.13 25.4
#     wv_LWAS      (time) float64 -0.1955 -0.8344 0.2689 ... 3.55 2.568 0.7803
#     wv_LWCS      (time) float64 -0.1278 -1.054 0.3798 ... 4.311 2.995 0.9209
#     wv_SWAS      (time) float64 0.0001857 -0.0008036 0.06053 ... 0.0169 0.0
#     wv_SWCS      (time) float64 0.0002284 0.004949 0.05053 ... 0.02063 0.0
#     wv_NETAS     (time) float64 -0.1954 -0.8352 0.3294 ... 3.949 2.585 0.7803
#     wv_NETCS     (time) float64 -0.1276 -1.049 0.4303 ... 4.751 3.015 0.9209
#     planck_LWAS  (time) float64 -8.643 -8.088 -4.195 ... -55.05 -63.7 -59.22
#     lapse_LWAS   (time) float64 3.159 4.76 2.109 1.221 ... 23.13 27.73 26.28
#     albedo_SWAS  (time) float64 0.0 -0.01103 -0.066 ... 2.319 0.04564 0.0
#     albedo_SWCS  (time) float64 0.0 -0.03022 -0.1542 ... 5.879 0.1176 0.0
#     cloud_LW     (time) float64 1.823 -0.2566 0.6627 ... 3.334 5.056 6.716
#     cloud_SW     (time) float64 -0.001043 0.02248 -0.3382 ... -0.03465 0.0
#     cloud_NET    (time) float64 1.822 -0.2341 0.3245 ... 1.579 5.021 6.716
#     atmos_conv   (time) float64 -10.53 -10.38 8.435 ... -9.827 -36.96 -60.88
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.9632 1.077 1.029 1.125 ... 5.85 6.045 6.116
#     wv_LWAS      (time) float64 0.4426 0.2329 0.972 1.268 ... 8.18 7.937 7.876
#     wv_LWCS      (time) float64 0.4758 0.5239 1.492 1.796 ... 11.25 11.02 11.1
#     wv_SWAS      (time) float64 0.1558 0.1846 0.2564 0.3058 ... 1.71 1.775 1.856
#     wv_SWCS      (time) float64 0.1251 0.1142 0.1349 ... 0.8755 0.9098 0.947
#     wv_NETAS     (time) float64 0.5984 0.4175 1.228 1.574 ... 9.89 9.712 9.732
#     wv_NETCS     (time) float64 0.6009 0.6382 1.627 1.982 ... 12.12 11.93 12.05
#     planck_LWAS  (time) float64 -2.567 -3.071 -3.139 ... -18.5 -18.71 -18.7
#     lapse_LWAS   (time) float64 0.2594 0.5008 -0.2126 ... -2.652 -3.122 -3.223
#     albedo_SWAS  (time) float64 0.04942 0.2598 0.3582 ... 2.048 2.534 2.699
#     albedo_SWCS  (time) float64 0.1469 0.5602 0.7408 ... 4.795 5.582 5.541
#     cloud_LW     (time) float64 0.6997 0.283 0.6522 0.5578 ... 2.615 2.543 2.569
#     cloud_SW     (time) float64 -0.5961 0.8951 0.1161 ... -3.64 -2.902 -3.717
#     cloud_NET    (time) float64 0.1036 1.178 0.7683 ... -1.024 -0.3593 -1.148
#     atmos_conv   (time) float64 1.506 -0.6907 -1.122 ... 0.3062 -0.2178 -0.3502
# GFDL-CM3
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -3.056 -5.099 4.284 -0.2474 ... 15.7 21.24 25.26
#     wv_LWAS      (time) float64 -0.2604 -0.6884 0.7979 ... 3.743 2.445 1.424
#     wv_LWCS      (time) float64 -0.2976 -0.7529 0.9416 ... 4.581 2.959 1.746
#     wv_SWAS      (time) float64 -0.0002346 -0.06108 0.4238 ... 0.01709 0.0
#     wv_SWCS      (time) float64 -0.0003301 -0.07461 0.4875 ... 0.02094 0.0
#     wv_NETAS     (time) float64 -0.2607 -0.7495 1.222 ... 4.184 2.463 1.424
#     wv_NETCS     (time) float64 -0.2979 -0.8275 1.429 ... 5.062 2.98 1.746
#     planck_LWAS  (time) float64 7.301 12.02 -10.27 ... -40.44 -51.63 -59.12
#     lapse_LWAS   (time) float64 -1.656 -3.134 1.319 -0.1405 ... 12.05 18.9 22.0
#     albedo_SWAS  (time) float64 -0.0001639 -0.03787 -0.3723 ... 0.04589 0.0
#     albedo_SWCS  (time) float64 -0.0005056 -0.1463 -0.8758 ... 3.21 0.08676 0.0
#     cloud_LW     (time) float64 0.1388 0.1491 1.526 0.9707 ... 7.06 14.26 17.73
#     cloud_SW     (time) float64 -0.001492 -0.002628 ... -0.03667 -4.226e-06
#     cloud_NET    (time) float64 0.1373 0.1464 1.347 1.577 ... 6.035 14.22 17.73
#     atmos_conv   (time) float64 14.99 -2.347 18.46 ... -23.75 -34.11 -22.85
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -0.4005 -0.2036 0.1199 ... 5.289 5.453 5.502
#     wv_LWAS      (time) float64 -1.383 -0.7876 -0.1769 ... 8.1 7.715 7.852
#     wv_LWCS      (time) float64 -1.734 -1.06 -0.3439 ... 10.76 10.34 10.47
#     wv_SWAS      (time) float64 -0.2081 -0.1172 0.02928 ... 1.409 1.393 1.431
#     wv_SWCS      (time) float64 -0.1057 -0.05126 0.08085 ... 0.7098 0.7307
#     wv_NETAS     (time) float64 -1.591 -0.9048 -0.1476 ... 9.509 9.108 9.283
#     wv_NETCS     (time) float64 -1.84 -1.111 -0.263 ... 11.47 11.05 11.2
#     planck_LWAS  (time) float64 1.347 0.7015 -0.1407 ... -17.31 -17.19 -16.93
#     lapse_LWAS   (time) float64 0.6112 0.4898 0.3484 ... -5.765 -4.75 -3.99
#     albedo_SWAS  (time) float64 -0.0092 0.05831 0.08957 ... 0.6885 0.6955 0.6245
#     albedo_SWCS  (time) float64 0.08107 0.2053 0.2035 ... 1.274 1.2 1.107
#     cloud_LW     (time) float64 -0.5866 -0.5119 0.6859 ... 1.448 2.343 3.279
#     cloud_SW     (time) float64 0.7131 0.9352 0.1537 ... 3.483 2.065 1.479
#     cloud_NET    (time) float64 0.1265 0.4233 0.8396 1.028 ... 4.931 4.409 4.758
#     atmos_conv   (time) float64 -1.476 -0.6378 0.09342 ... 2.48 1.444 -3.295
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# inmcm4
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 2090-01-16 12:00:00 ... 2239-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 1.801 -1.615 -0.5602 1.725 ... 9.001 12.21 11.2
#     wv_LWAS      (time) float64 0.5843 0.3078 -0.5366 ... 1.68 0.4335 0.454
#     wv_LWCS      (time) float64 0.7371 0.3906 -0.6122 ... 2.13 0.5769 0.5619
#     wv_SWAS      (time) float64 0.000214 -0.008945 -0.08228 ... 0.006393 0.0
#     wv_SWCS      (time) float64 0.0002743 -0.01419 -0.08531 ... 0.008359 0.0
#     wv_NETAS     (time) float64 0.5846 0.2988 -0.6188 ... 1.87 0.4399 0.454
#     wv_NETCS     (time) float64 0.7373 0.3764 -0.6975 ... 2.332 0.5852 0.5619
#     planck_LWAS  (time) float64 -4.1 3.863 1.371 -4.255 ... -23.24 -29.67 -26.48
#     lapse_LWAS   (time) float64 0.622 -2.811 -0.02684 1.651 ... 9.314 14.3 11.1
#     albedo_SWAS  (time) float64 -0.0001097 -0.01864 -0.08584 ... 0.02307 0.0
#     albedo_SWCS  (time) float64 -0.0001979 -0.04848 -0.2395 ... 2.74 0.05289 0.0
#     cloud_LW     (time) float64 0.5376 0.5387 0.1171 0.773 ... 4.096 3.563 2.775
#     cloud_SW     (time) float64 0.00255 0.07102 -0.09618 ... -0.00904 0.0
#     cloud_NET    (time) float64 0.5402 0.6097 0.02093 ... 3.581 3.554 2.775
#     atmos_conv   (time) float64 37.78 6.693 -3.213 ... -5.761 -21.48 -16.97
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 2090-01-16 12:00:00 ... 2239-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.4222 0.3322 0.452 0.6769 ... 3.029 3.264 3.274
#     wv_LWAS      (time) float64 0.2175 0.2166 0.2744 ... 4.397 3.956 3.924
#     wv_LWCS      (time) float64 0.1589 0.2449 0.3888 1.134 ... 5.979 5.387 5.413
#     wv_SWAS      (time) float64 0.04778 0.02978 0.03529 ... 0.8404 0.8032 0.8302
#     wv_SWCS      (time) float64 0.05308 0.02857 0.02153 ... 0.4325 0.4341 0.4394
#     wv_NETAS     (time) float64 0.2652 0.2464 0.3097 ... 5.237 4.759 4.755
#     wv_NETCS     (time) float64 0.212 0.2735 0.4103 1.224 ... 6.412 5.821 5.853
#     planck_LWAS  (time) float64 -1.257 -1.154 -1.426 ... -9.753 -10.12 -10.12
#     lapse_LWAS   (time) float64 -0.2146 -0.6646 -0.5624 ... -1.748 -1.955 -1.852
#     albedo_SWAS  (time) float64 0.07391 0.08242 0.0611 ... 1.012 1.573 1.418
#     albedo_SWCS  (time) float64 0.03465 0.08872 0.1218 ... 2.039 2.845 2.563
#     cloud_LW     (time) float64 0.587 0.9643 0.643 0.9884 ... 2.054 1.94 1.452
#     cloud_SW     (time) float64 -0.5384 0.295 -0.05015 ... -1.32 -1.822 -1.528
#     cloud_NET    (time) float64 0.04865 1.259 0.5928 ... 0.734 0.1184 -0.07528
#     atmos_conv   (time) float64 0.4143 -0.6254 0.5622 ... -1.021 0.2019 0.3329
# IPSL-CM5A-LR
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 1.593 2.596 1.964 2.552 ... 16.7 22.25 17.16
#     wv_LWAS      (time) float64 -0.3719 0.1708 0.09615 ... 3.861 3.221 1.03
#     wv_LWCS      (time) float64 -0.5776 0.2403 0.1209 ... 4.756 3.896 1.376
#     wv_SWAS      (time) float64 5.875e-05 0.02342 -0.08803 ... 0.4177 0.0178 0.0
#     wv_SWCS      (time) float64 0.0001194 0.0292 -0.08361 ... 0.4489 0.02138 0.0
#     wv_NETAS     (time) float64 -0.3718 0.1942 0.008126 ... 4.279 3.239 1.03
#     wv_NETCS     (time) float64 -0.5775 0.2695 0.0373 ... 5.205 3.918 1.376
#     planck_LWAS  (time) float64 -3.781 -6.113 -4.843 ... -42.97 -54.55 -41.1
#     lapse_LWAS   (time) float64 3.831 2.58 1.682 2.13 ... 15.65 20.68 16.61
#     albedo_SWAS  (time) float64 0.0 0.01215 0.1649 0.6656 ... 1.442 0.02219 0.0
#     albedo_SWCS  (time) float64 0.0 0.07941 0.7163 1.329 ... 3.606 0.06337 0.0
#     cloud_LW     (time) float64 0.5096 1.897 -1.696 0.6956 ... 8.6 11.32 6.016
#     cloud_SW     (time) float64 -0.002006 -0.07662 0.8376 ... -2.169 -0.0663 0.0
#     cloud_NET    (time) float64 0.5076 1.82 -0.8587 0.2019 ... 6.431 11.26 6.016
#     atmos_conv   (time) float64 -17.66 2.173 4.618 ... -4.932 0.1911 -21.47
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.5342 0.7953 0.8112 1.001 ... 5.967 5.977 6.03
#     wv_LWAS      (time) float64 0.314 1.11 1.494 1.734 ... 9.722 9.8 9.655 9.332
#     wv_LWCS      (time) float64 0.3564 1.439 1.914 2.237 ... 13.21 12.97 12.64
#     wv_SWAS      (time) float64 -0.01342 0.1386 0.2071 ... 1.746 1.71 1.752
#     wv_SWCS      (time) float64 -0.004925 0.06807 0.09102 ... 0.8273 0.8479
#     wv_NETAS     (time) float64 0.3006 1.248 1.701 1.988 ... 11.55 11.36 11.08
#     wv_NETCS     (time) float64 0.3515 1.507 2.005 2.382 ... 14.08 13.79 13.49
#     planck_LWAS  (time) float64 -1.677 -2.489 -2.61 ... -19.54 -19.13 -19.14
#     lapse_LWAS   (time) float64 -0.041 -0.7991 -1.282 ... -5.236 -5.509 -5.349
#     albedo_SWAS  (time) float64 0.06021 0.07131 0.1084 ... 1.072 1.007 0.6856
#     albedo_SWCS  (time) float64 0.1069 0.1708 0.1992 0.5122 ... 2.24 1.915 1.308
#     cloud_LW     (time) float64 -0.2355 -0.3568 -0.2123 ... 0.7214 1.67 1.401
#     cloud_SW     (time) float64 2.669 2.335 2.228 2.475 ... 6.786 5.801 6.727
#     cloud_NET    (time) float64 2.433 1.978 2.016 2.632 ... 7.506 7.471 8.128
#     atmos_conv   (time) float64 0.2018 -2.093 -0.3947 ... 0.2865 0.3727 -2.426
# MIROC5
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 2100-01-16 12:00:00 ... 2249-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 2.235 2.321 4.667 4.311 ... 18.71 23.66 24.95
#     wv_LWAS      (time) float64 -0.04185 -0.2471 0.401 ... 2.692 1.765 0.08544
#     wv_LWCS      (time) float64 0.03971 -0.1834 0.4192 ... 3.441 2.196 0.3265
#     wv_SWAS      (time) float64 -0.0001301 -0.02258 0.2973 ... 0.01323 0.0
#     wv_SWCS      (time) float64 -0.0002208 -0.024 0.3513 ... 0.4922 0.01676 0.0
#     wv_NETAS     (time) float64 -0.04198 -0.2696 0.6983 ... 3.115 1.779 0.08544
#     wv_NETCS     (time) float64 0.03949 -0.2074 0.7705 ... 3.933 2.213 0.3265
#     planck_LWAS  (time) float64 -5.441 -5.505 -11.24 ... -48.87 -57.9 -59.13
#     lapse_LWAS   (time) float64 2.075 2.146 3.386 3.417 ... 20.44 25.11 26.5
#     albedo_SWAS  (time) float64 -0.0001706 -0.002344 0.1452 ... 0.05235 0.0
#     albedo_SWCS  (time) float64 -0.0003377 0.03954 0.444 ... 5.949 0.1207 0.0
#     cloud_LW     (time) float64 0.3763 0.8314 0.9532 ... 4.999 5.456 6.228
#     cloud_SW     (time) float64 -0.0004022 -0.003815 -0.02713 ... -0.01909 0.0
#     cloud_NET    (time) float64 0.3759 0.8276 0.9261 1.005 ... 3.862 5.437 6.228
#     atmos_conv   (time) float64 8.918 2.449 2.447 4.677 ... -13.86 -17.48 -20.76
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 2100-01-16 12:00:00 ... 2249-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.2981 0.4371 0.5899 0.816 ... 4.143 4.202 4.322
#     wv_LWAS      (time) float64 0.2676 0.2607 0.4471 ... 5.885 5.485 5.191
#     wv_LWCS      (time) float64 0.2848 0.2319 0.6265 1.138 ... 7.819 7.512 7.12
#     wv_SWAS      (time) float64 0.03155 -0.001571 0.07447 ... 1.066 0.9831 1.012
#     wv_SWCS      (time) float64 0.03768 0.01514 0.05369 ... 0.5802 0.4936 0.5042
#     wv_NETAS     (time) float64 0.2991 0.2591 0.5215 0.978 ... 6.951 6.468 6.203
#     wv_NETCS     (time) float64 0.3225 0.247 0.6802 1.235 ... 8.399 8.006 7.624
#     planck_LWAS  (time) float64 -0.8906 -1.395 -1.833 ... -13.39 -13.18 -13.23
#     lapse_LWAS   (time) float64 -0.519 -0.4245 -0.566 ... -2.943 -2.82 -1.971
#     albedo_SWAS  (time) float64 -0.05214 0.05226 0.1395 ... 0.408 0.3182 0.3395
#     albedo_SWCS  (time) float64 -0.05225 0.1633 0.3386 ... 0.9483 0.6867 0.6801
#     cloud_LW     (time) float64 -0.425 -0.8685 -0.3348 ... 0.3676 0.7642 0.7025
#     cloud_SW     (time) float64 1.218 2.218 1.656 ... -0.07916 -0.3592 0.3844
#     cloud_NET    (time) float64 0.7933 1.349 1.321 1.388 ... 0.2892 0.4051 1.087
#     atmos_conv   (time) float64 1.558 -0.07901 -0.6237 ... 2.423 -0.3871 1.772
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# MPI-ESM-LR
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -0.7869 0.8366 -0.6618 ... 15.6 20.96 23.99
#     wv_LWAS      (time) float64 -0.249 -0.4973 -0.03693 ... 4.04 2.791 1.878
#     wv_LWCS      (time) float64 -0.3525 -0.5609 -0.12 ... 5.015 3.444 2.237
#     wv_SWAS      (time) float64 -0.0001578 -0.02942 -0.1746 ... 0.0175 0.0
#     wv_SWCS      (time) float64 -0.0002057 -0.03737 -0.2075 ... 0.02133 0.0
#     wv_NETAS     (time) float64 -0.2492 -0.5267 -0.2115 ... 4.483 2.808 1.878
#     wv_NETCS     (time) float64 -0.3527 -0.5983 -0.3275 ... 5.489 3.465 2.237
#     planck_LWAS  (time) float64 1.945 -1.94 1.707 ... -39.92 -51.01 -56.02
#     lapse_LWAS   (time) float64 -0.08791 0.4681 -1.11 ... 12.07 18.52 18.54
#     albedo_SWAS  (time) float64 -5.673e-05 -0.01643 -0.1671 ... 0.06478 0.0
#     albedo_SWCS  (time) float64 -0.0001976 -0.05825 -0.4107 ... 4.755 0.1332 0.0
#     cloud_LW     (time) float64 -0.4663 -1.295 -0.1598 ... 9.343 10.46 12.1
#     cloud_SW     (time) float64 0.002224 0.007158 0.3885 ... -0.07626 -0.001621
#     cloud_NET    (time) float64 -0.464 -1.288 0.2287 ... 6.828 10.38 12.1
#     atmos_conv   (time) float64 12.77 7.557 -9.121 ... 2.808 -14.81 -30.66
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.3144 0.4063 0.4778 ... 5.754 5.885 6.099
#     wv_LWAS      (time) float64 -0.747 -0.0265 0.1768 ... 9.344 8.729 8.559
#     wv_LWCS      (time) float64 -1.046 -0.06694 0.1412 ... 12.67 11.86 11.61
#     wv_SWAS      (time) float64 -0.08881 0.004137 0.003881 ... 1.72 1.612 1.546
#     wv_SWCS      (time) float64 -0.01426 -0.008106 0.003278 ... 0.8301 0.7486
#     wv_NETAS     (time) float64 -0.8359 -0.02236 0.1807 ... 11.06 10.34 10.11
#     wv_NETCS     (time) float64 -1.06 -0.07505 0.1445 ... 13.53 12.69 12.36
#     planck_LWAS  (time) float64 -1.029 -1.438 -1.744 ... -18.72 -18.68 -18.85
#     lapse_LWAS   (time) float64 0.8874 0.2916 -0.08649 ... -5.128 -4.652 -5.042
#     albedo_SWAS  (time) float64 -0.08457 0.01598 0.04872 ... 1.188 1.385 1.251
#     albedo_SWCS  (time) float64 -0.2109 -0.02981 -0.02007 ... 2.617 2.734 2.286
#     cloud_LW     (time) float64 -0.6728 -0.1292 -0.1632 ... 2.779 2.871 3.475
#     cloud_SW     (time) float64 3.157 2.489 1.937 2.098 ... 1.032 0.4068 -0.3358
#     cloud_NET    (time) float64 2.484 2.36 1.774 2.497 ... 3.81 3.278 3.139
#     atmos_conv   (time) float64 0.5698 -1.212 -0.9286 ... 1.808 0.3795 -0.6435
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# MPI-ESM-P
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 2.584 4.885 3.957 3.479 ... 14.72 19.8 22.57
#     wv_LWAS      (time) float64 0.2002 0.3035 0.4831 ... 4.422 2.563 1.332
#     wv_LWCS      (time) float64 0.2688 0.4196 0.5333 0.8051 ... 5.376 3.09 1.632
#     wv_SWAS      (time) float64 0.0001403 0.0465 0.3098 ... 0.4453 0.01593 0.0
#     wv_SWCS      (time) float64 0.0001108 0.0605 0.3599 ... 0.4733 0.01903 0.0
#     wv_NETAS     (time) float64 0.2004 0.35 0.7929 1.63 ... 4.867 2.579 1.332
#     wv_NETCS     (time) float64 0.2689 0.4801 0.8932 1.909 ... 5.849 3.109 1.632
#     planck_LWAS  (time) float64 -6.018 -11.37 -9.592 ... -37.71 -48.03 -52.76
#     lapse_LWAS   (time) float64 3.267 2.933 1.904 2.025 ... 9.86 17.34 19.32
#     albedo_SWAS  (time) float64 -1.399e-05 -0.003125 0.3282 ... 0.05234 0.0
#     albedo_SWCS  (time) float64 9.26e-05 0.02098 0.828 ... 4.407 0.1094 0.0
#     cloud_LW     (time) float64 2.345 0.7447 1.394 2.246 ... 7.745 10.83 10.68
#     cloud_SW     (time) float64 -0.001839 -0.05069 ... -0.07153 -0.002046
#     cloud_NET    (time) float64 2.343 0.694 1.45 0.4476 ... 4.889 10.76 10.68
#     atmos_conv   (time) float64 16.55 22.1 -6.559 2.234 ... -1.319 -17.73 -18.17
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.5545 0.7701 0.841 0.9466 ... 5.764 5.853 5.859
#     wv_LWAS      (time) float64 -0.04319 0.07461 0.6055 ... 8.829 8.632 8.847
#     wv_LWCS      (time) float64 -0.08552 0.2201 0.8125 ... 11.8 11.53 11.95
#     wv_SWAS      (time) float64 -0.02477 0.048 0.0768 ... 1.616 1.588 1.596
#     wv_SWCS      (time) float64 0.0004836 0.02453 0.03591 ... 0.8212 0.7928
#     wv_NETAS     (time) float64 -0.06796 0.1226 0.6823 ... 10.44 10.22 10.44
#     wv_NETCS     (time) float64 -0.08504 0.2446 0.8484 ... 12.62 12.36 12.74
#     planck_LWAS  (time) float64 -1.703 -2.346 -2.675 ... -18.79 -18.72 -18.33
#     lapse_LWAS   (time) float64 0.699 0.01395 -0.1122 ... -4.543 -4.281 -4.82
#     albedo_SWAS  (time) float64 0.0952 0.1658 0.08195 ... 1.545 1.749 1.313
#     albedo_SWCS  (time) float64 0.1227 0.2941 0.1839 ... 3.183 3.271 2.352
#     cloud_LW     (time) float64 0.4012 -0.2857 0.1088 ... 2.197 3.02 3.635
#     cloud_SW     (time) float64 2.067 2.592 3.255 2.526 ... 2.276 0.3267 0.7323
#     cloud_NET    (time) float64 2.468 2.306 3.364 2.829 ... 4.472 3.346 4.367
#     atmos_conv   (time) float64 -1.411 0.8805 -2.029 ... 2.091 -0.05655 1.16
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# MRI-CGCM3
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1851-01-16 12:00:00 ... 2000-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 1.154 4.701 3.268 4.693 ... 17.6 24.18 22.38
#     wv_LWAS      (time) float64 0.4097 -0.14 0.3209 0.2253 ... 2.62 1.725 0.9611
#     wv_LWCS      (time) float64 0.5212 -0.1436 0.4022 ... 3.356 2.164 1.27
#     wv_SWAS      (time) float64 7.596e-05 0.01101 0.2286 ... 0.3201 0.01359 0.0
#     wv_SWCS      (time) float64 5.778e-05 0.01639 0.2592 ... 0.3437 0.01687 0.0
#     wv_NETAS     (time) float64 0.4098 -0.129 0.5495 1.041 ... 2.94 1.738 0.9611
#     wv_NETCS     (time) float64 0.5213 -0.1272 0.6614 1.256 ... 3.7 2.181 1.27
#     planck_LWAS  (time) float64 -2.743 -11.0 -7.986 ... -44.84 -59.25 -53.01
#     lapse_LWAS   (time) float64 1.669 5.556 2.773 4.948 ... 20.58 26.52 21.31
#     albedo_SWAS  (time) float64 0.0001239 0.01315 0.2123 ... 1.577 0.02799 0.0
#     albedo_SWCS  (time) float64 0.0003501 0.06492 0.7472 ... 3.887 0.08491 0.0
#     cloud_LW     (time) float64 0.9412 -0.4407 -0.05642 ... 4.302 3.422 3.349
#     cloud_SW     (time) float64 -0.0003012 0.009526 0.06149 ... 0.01552 0.0
#     cloud_NET    (time) float64 0.9409 -0.4312 0.005062 ... 4.288 3.438 3.349
#     atmos_conv   (time) float64 -3.395 -1.58 5.537 4.23 ... -19.04 -25.57 -23.99
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1851-01-16 12:00:00 ... 2000-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.05722 0.4276 0.6348 0.7006 ... 4.535 5.0 4.992
#     wv_LWAS      (time) float64 -0.5276 0.1261 0.3345 ... 6.143 5.966 5.877
#     wv_LWCS      (time) float64 -0.591 0.1661 0.5169 0.9617 ... 8.343 7.992 7.87
#     wv_SWAS      (time) float64 -0.08884 0.06668 0.1034 ... 1.169 1.156 1.198
#     wv_SWCS      (time) float64 -0.05565 0.05283 0.06873 ... 0.6249 0.6551
#     wv_NETAS     (time) float64 -0.6164 0.1928 0.4379 ... 7.312 7.122 7.075
#     wv_NETCS     (time) float64 -0.6467 0.2189 0.5856 1.12 ... 8.938 8.617 8.526
#     planck_LWAS  (time) float64 -0.08685 -1.175 -1.908 ... -14.48 -15.5 -15.15
#     lapse_LWAS   (time) float64 -0.3988 0.2458 -0.2602 ... -2.548 -2.047 -1.81
#     albedo_SWAS  (time) float64 0.01595 0.0541 0.1577 ... 1.27 1.832 1.773
#     albedo_SWCS  (time) float64 0.01738 0.08627 0.3385 ... 2.869 3.604 3.392
#     cloud_LW     (time) float64 0.2168 0.7173 0.5914 ... 1.089 0.6608 0.8009
#     cloud_SW     (time) float64 0.7275 0.1708 0.489 ... 0.7597 0.8327 -0.07088
#     cloud_NET    (time) float64 0.9443 0.8882 1.08 0.7011 ... 1.848 1.493 0.7301
#     atmos_conv   (time) float64 -0.05341 -1.436 -0.2863 ... 0.04904 -0.971 1.498
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# NorESM1-M
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -1.21 3.982 0.4271 1.738 ... 17.78 22.27 22.04
#     wv_LWAS      (time) float64 -0.3215 0.1464 -0.7911 ... 3.09 1.984 1.001
#     wv_LWCS      (time) float64 -0.2971 0.2454 -0.9656 ... 3.874 2.485 1.163
#     wv_SWAS      (time) float64 -0.0001309 0.03752 -0.134 ... 0.3644 0.01234 0.0
#     wv_SWCS      (time) float64 -0.0001565 0.05148 -0.1445 ... 0.01515 0.0
#     wv_NETAS     (time) float64 -0.3216 0.184 -0.9251 ... 3.454 1.997 1.001
#     wv_NETCS     (time) float64 -0.2973 0.2969 -1.11 0.408 ... 4.273 2.501 1.163
#     planck_LWAS  (time) float64 2.851 -9.274 -0.9079 ... -45.41 -54.16 -51.74
#     lapse_LWAS   (time) float64 0.3414 3.581 1.952 1.938 ... 19.33 23.26 21.21
#     albedo_SWAS  (time) float64 0.0 0.005856 0.09288 ... 2.099 0.03378 0.0
#     albedo_SWCS  (time) float64 0.0 0.03828 0.174 -0.1361 ... 5.263 0.08078 0.0
#     cloud_LW     (time) float64 1.237 1.122 0.2008 1.819 ... 9.283 8.791 8.867
#     cloud_SW     (time) float64 -0.0001692 -0.03832 0.06725 ... -0.03489 0.0
#     cloud_NET    (time) float64 1.237 1.084 0.268 1.236 ... 7.653 8.756 8.867
#     atmos_conv   (time) float64 18.7 6.932 -15.3 0.7501 ... 4.589 7.758 -29.01
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.2917 0.5093 0.6864 0.6845 ... 4.35 4.377 4.476
#     wv_LWAS      (time) float64 -0.5121 -0.1099 0.3257 ... 5.504 5.066 4.823
#     wv_LWCS      (time) float64 -0.5454 -0.0568 0.4424 ... 7.436 6.901 6.641
#     wv_SWAS      (time) float64 -0.07765 -0.003971 0.03578 ... 0.9773 1.026
#     wv_SWCS      (time) float64 -0.05527 -0.008467 0.007802 ... 0.513 0.5184
#     wv_NETAS     (time) float64 -0.5898 -0.1138 0.3615 ... 6.572 6.043 5.849
#     wv_NETCS     (time) float64 -0.6007 -0.06527 0.4502 ... 8.012 7.414 7.159
#     planck_LWAS  (time) float64 -0.717 -1.43 -2.021 ... -13.71 -13.49 -13.46
#     lapse_LWAS   (time) float64 -0.07945 0.3066 -0.2385 ... -1.872 -1.366 -1.583
#     albedo_SWAS  (time) float64 -0.172 0.06461 0.3019 ... 0.886 0.9518 0.9627
#     albedo_SWCS  (time) float64 -0.4019 0.06871 0.5582 ... 2.136 2.044 1.92
#     cloud_LW     (time) float64 -0.1227 -0.0567 0.2611 ... 1.562 1.475 1.454
#     cloud_SW     (time) float64 1.527 1.981 1.358 ... -0.03515 -0.0007472
#     cloud_NET    (time) float64 1.405 1.925 1.619 1.914 ... 0.9697 1.44 1.454
#     atmos_conv   (time) float64 0.7106 0.7979 -1.748 ... 0.4033 1.794 -0.1584
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>

# %%
def spatial_mean(ds,lat_south=-91,lat_north=91):
    """Take the mean over latitude and longitude dimensions,
    while weighting for latitude.

    PARAMETERS
    ----------
    datasets : list of xarray.Dataset
        A list of xarray datasets to return .

    RETURNS
    -------
    filelist : A list of xarray datasets retrieved from server.
    """
    area_of_int = ds.mean(dim='lon').sel(lat = slice(lat_south, lat_north))
    weights = (np.cos(np.deg2rad(area_of_int['lat']))/
               np.sum(np.cos(np.deg2rad(area_of_int['lat']))))
    return((area_of_int * weights).sum(dim='lat'))

# %%
models = ['ACCESS1-0','ACCESS1-3','CNRM-CM5','IPSL-CM5B-LR', 'GFDL-ESM2G',
         'MIROC-ESM', 'FGOALS-g2','bcc-csm1-1','BNU-ESM','CanESM2','CCSM4',
          'CSIRO-Mk3-6-0','FGOALS-s2','GFDL-CM3','inmcm4',
         'IPSL-CM5A-LR','MIROC5','MPI-ESM-LR','MPI-ESM-P','MRI-CGCM3','NorESM1-M']
for m in models:
    print(m)
    ts = xr.open_dataset('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_dTs.nc',use_cftime=True).load()
    wv = xr.open_dataset('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_wv.nc',use_cftime=True).load()
    planck = xr.open_dataset('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_planck.nc',use_cftime=True).load()
    lapse = xr.open_dataset('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_lapse.nc',use_cftime=True).load()
    alb = xr.open_dataset('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_albedo.nc',use_cftime=True).load()
    cloud = xr.open_dataset('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_cloud.nc',use_cftime=True).load()
    atmos = xr.open_dataarray('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_atmos_conv.nc',use_cftime=True).load().to_dataset(name='atmos_conv')
    
    subarc = xr.merge([spatial_mean(i,lat_south=70) for i in [ts,wv,planck,lapse,alb,cloud,atmos]])
    trop = xr.merge([spatial_mean(i,lat_south=-30,lat_north=30) for i in [ts,wv,planck,lapse,alb,cloud,atmos]])
        
    if m in ['BNU-ESM','CCSM4','CSIRO-Mk3-6-0','GFDL-CM3','MIROC5',
               'MPI-ESM-LR','MPI-ESM-P','MRI-CGCM3','NorESM1-M','ACCESS1-0','ACCESS1-3',
              'CNRM-CM5','FGOALS-g2','MIROC-ESM']:
        ocean = xr.open_dataarray('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_ocean_conv.nc',use_cftime=True).load()
        if(m in ['CCSM4','FGOALS-g2']):
            ocean['time'] = ts.time
        areacello = xr.open_mfdataset('/dx07/tylerj/CMIP5_output/piControl/areacello_fx_'+m+'_*.nc',
                                     combine='by_coords').areacello
        weights_subarc = areacello.where(areacello.lat>60) / areacello.where(areacello.lat>60).sum().sum()
        weights_trop = areacello.where(abs(areacello.lat)<=30) / areacello.where(abs(areacello.lat)<=30).sum().sum()
        ocean_subarc = (weights_subarc * ocean).sum(axis=[0,1]).to_dataset(name='ml_conv')
        ocean_trop = (weights_trop * ocean).sum(axis=[0,1]).to_dataset(name='ml_conv')
        subarc = xr.merge([subarc,ocean_subarc])
        trop = xr.merge([trop,ocean_trop])
    
    print(subarc)
    print(trop)
    
    subarc.to_netcdf('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_subarc_feedbacks.nc')
    trop.to_netcdf('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/'+m+'_trop_feedbacks.nc')
# Out:
# ACCESS1-0
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0300-01-16 12:00:00 ... 0449-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -2.148 1.832 -0.6739 ... 15.69 20.42 24.31
#     wv_LWAS      (time) float64 -0.6372 -0.1257 -0.4374 ... 3.474 1.874 0.889
#     wv_LWCS      (time) float64 -0.7117 -0.2108 -0.5215 ... 4.33 2.348 1.067
#     wv_SWAS      (time) float64 -0.0002106 0.0004562 -0.0157 ... 0.01522 0.0
#     wv_SWCS      (time) float64 -0.0002578 0.00262 -0.01264 ... 0.01877 0.0
#     wv_NETAS     (time) float64 -0.6374 -0.1252 -0.4531 ... 3.894 1.889 0.889
#     wv_NETCS     (time) float64 -0.712 -0.2082 -0.5341 ... 4.782 2.367 1.067
#     planck_LWAS  (time) float64 5.176 -4.077 1.764 ... -40.36 -49.64 -57.18
#     lapse_LWAS   (time) float64 -0.8058 0.6242 -2.019 ... 15.38 20.25 23.04
#     albedo_SWAS  (time) float64 -0.0006216 -0.05722 -0.4644 ... 0.06601 0.0
#     albedo_SWCS  (time) float64 -0.0007893 -0.09346 -0.7501 ... 0.08547 0.0
#     cloud_LW     (time) float64 -1.204 -1.246 -2.285 ... 7.289 9.793 12.99
#     cloud_SW     (time) float64 0.00125 0.06736 0.6714 ... -1.271 -0.02671 0.0
#     cloud_NET    (time) float64 -1.203 -1.179 -1.613 0.494 ... 6.018 9.767 12.99
#     atmos_conv   (time) float64 11.03 14.02 7.314 ... -20.13 -29.35 -20.68
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0300-01-16 12:00:00 ... 0449-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.1625 0.3522 0.5255 ... 4.771 4.675 4.704
#     wv_LWAS      (time) float64 -0.9831 -1.042 -0.8227 ... 9.955 10.19 10.48
#     wv_LWCS      (time) float64 -1.249 -1.352 -0.8997 ... 13.54 13.58 13.95
#     wv_SWAS      (time) float64 -0.1005 -0.194 -0.06484 ... 1.614 1.56 1.491
#     wv_SWCS      (time) float64 -0.04162 -0.1044 0.02096 ... 0.7109 0.6977
#     wv_NETAS     (time) float64 -1.084 -1.236 -0.8875 ... 11.57 11.75 11.97
#     wv_NETCS     (time) float64 -1.291 -1.456 -0.8787 ... 14.28 14.29 14.65
#     planck_LWAS  (time) float64 -0.572 -1.199 -1.846 ... -17.19 -16.85 -16.87
#     lapse_LWAS   (time) float64 0.3872 0.4177 0.0538 ... -6.083 -6.302 -6.314
#     albedo_SWAS  (time) float64 -0.08042 0.02484 -0.007178 ... -0.07503 -0.03446
#     albedo_SWCS  (time) float64 -0.1157 0.02906 -0.01052 ... -0.111 -0.0642
#     cloud_LW     (time) float64 -0.002316 -0.8632 0.3514 ... 2.124 2.767 3.089
#     cloud_SW     (time) float64 1.703 2.946 0.4729 0.6109 ... 3.611 2.032 2.774
#     cloud_NET    (time) float64 1.701 2.083 0.8243 0.465 ... 5.735 4.799 5.863
#     atmos_conv   (time) float64 -1.911 -0.5583 -4.747 ... -2.433 -3.232 -2.273
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# ACCESS1-3
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0250-01-16 12:00:00 ... 0399-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 1.897 1.542 1.957 2.531 ... 14.68 19.01 22.05
#     wv_LWAS      (time) float64 0.03589 -0.1023 0.007198 ... 3.636 2.035 0.6172
#     wv_LWCS      (time) float64 0.06707 -0.1372 0.01935 ... 4.561 2.49 0.7676
#     wv_SWAS      (time) float64 3.93e-05 -0.002863 0.06731 ... 0.01455 0.0
#     wv_SWCS      (time) float64 3.309e-05 -0.001554 0.07437 ... 0.01756 0.0
#     wv_NETAS     (time) float64 0.03593 -0.1051 0.07451 ... 4.028 2.05 0.6172
#     wv_NETCS     (time) float64 0.0671 -0.1388 0.09372 ... 4.981 2.507 0.7676
#     planck_LWAS  (time) float64 -4.543 -3.633 -4.69 ... -38.05 -46.23 -51.85
#     lapse_LWAS   (time) float64 1.154 1.836 1.832 1.944 ... 11.87 16.74 21.12
#     albedo_SWAS  (time) float64 0.0001332 0.04742 0.5123 ... 2.674 0.07526 0.0
#     albedo_SWCS  (time) float64 0.0001858 0.07256 0.7461 ... 3.582 0.09501 0.0
#     cloud_LW     (time) float64 0.5456 -0.2874 1.069 1.887 ... 6.543 5.151 6.814
#     cloud_SW     (time) float64 0.001157 0.02246 -0.2816 ... -0.03318 0.0
#     cloud_NET    (time) float64 0.5468 -0.265 0.7871 0.8856 ... 5.72 5.118 6.814
#     atmos_conv   (time) float64 13.81 -9.189 -4.419 1.768 ... 6.563 -12.88 -35.8
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0250-01-16 12:00:00 ... 0399-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.04354 0.1093 0.1034 ... 4.586 4.359 4.195
#     wv_LWAS      (time) float64 -0.894 -1.057 -0.6861 ... 9.446 8.473 8.918
#     wv_LWCS      (time) float64 -1.134 -1.457 -0.8669 ... 12.69 11.48 11.9
#     wv_SWAS      (time) float64 -0.07982 -0.1269 -0.02254 ... 1.492 1.364 1.363
#     wv_SWCS      (time) float64 -0.006064 0.005947 0.0128 ... 0.6217 0.6602
#     wv_NETAS     (time) float64 -0.9738 -1.184 -0.7086 ... 10.94 9.837 10.28
#     wv_NETCS     (time) float64 -1.14 -1.451 -0.8541 ... 13.37 12.1 12.56
#     planck_LWAS  (time) float64 -0.1409 -0.4213 -0.39 ... -16.56 -15.77 -15.18
#     lapse_LWAS   (time) float64 0.6653 0.3171 0.4389 ... -5.476 -5.607 -4.79
#     albedo_SWAS  (time) float64 -0.001807 0.00489 0.02109 ... -0.0837 -0.02763
#     albedo_SWCS  (time) float64 0.0006789 0.01092 0.0385 ... -0.1399 -0.04641
#     cloud_LW     (time) float64 0.5224 0.1255 0.8152 ... 0.3224 -0.1855 0.542
#     cloud_SW     (time) float64 0.8667 -0.1771 0.3307 ... 4.706 4.74 6.008
#     cloud_NET    (time) float64 1.389 -0.05162 1.146 0.5289 ... 5.028 4.555 6.55
#     atmos_conv   (time) float64 2.525 -1.879 -1.557 ... 0.2966 0.124 -0.8646
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# CNRM-CM5
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 4.526 -0.0243 3.119 3.287 ... 16.09 21.78 24.99
#     wv_LWAS      (time) float64 -0.403 0.305 0.6119 ... 4.155 1.809 0.9206
#     wv_LWCS      (time) float64 -0.3111 0.5538 0.6623 ... 5.21 2.329 1.171
#     wv_SWAS      (time) float64 5.678e-05 -0.01141 0.2454 ... 0.4347 0.01336 0.0
#     wv_SWCS      (time) float64 8.074e-05 -0.01199 0.276 ... 0.4744 0.01687 0.0
#     wv_NETAS     (time) float64 -0.4029 0.2936 0.8573 ... 4.59 1.822 0.9206
#     wv_NETCS     (time) float64 -0.311 0.5418 0.9383 1.707 ... 5.684 2.346 1.171
#     planck_LWAS  (time) float64 -10.86 -0.2521 -7.605 ... -41.88 -53.34 -59.51
#     lapse_LWAS   (time) float64 5.49 1.591 1.171 1.914 ... 12.76 21.88 23.23
#     albedo_SWAS  (time) float64 6.96e-06 0.03434 0.5072 ... 3.181 0.07919 0.0
#     albedo_SWCS  (time) float64 0.0003079 0.1203 1.205 ... 4.502 0.1043 0.0
#     cloud_LW     (time) float64 -0.3505 0.5106 0.2662 0.3905 ... 6.04 6.482 7.41
#     cloud_SW     (time) float64 -0.002722 -0.005295 0.135 ... -0.03322 0.0
#     cloud_NET    (time) float64 -0.3533 0.5053 0.4012 ... 5.126 6.449 7.41
#     atmos_conv   (time) float64 -2.092 -3.901 -1.449 ... 5.421 -7.63 -21.33
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.2171 0.5542 0.6676 ... 4.483 4.515 4.438
#     wv_LWAS      (time) float64 -0.5706 0.3571 0.8386 ... 9.373 9.771 8.931
#     wv_LWCS      (time) float64 -0.6109 0.3602 0.9229 ... 12.7 12.77 11.92
#     wv_SWAS      (time) float64 -0.05099 -0.03287 0.06968 ... 1.538 1.477 1.325
#     wv_SWCS      (time) float64 0.01511 0.03783 0.08745 ... 0.7377 0.7245 0.6265
#     wv_NETAS     (time) float64 -0.6216 0.3242 0.9083 ... 10.91 11.25 10.26
#     wv_NETCS     (time) float64 -0.5958 0.3981 1.01 0.633 ... 13.44 13.49 12.55
#     planck_LWAS  (time) float64 -0.8048 -2.031 -2.412 ... -16.25 -16.39 -16.03
#     lapse_LWAS   (time) float64 -0.4507 -0.7075 -0.7054 ... -5.116 -5.467 -5.944
#     albedo_SWAS  (time) float64 0.03104 0.04609 0.04458 ... 0.2442 0.233 0.2313
#     albedo_SWCS  (time) float64 0.03698 0.07981 0.07149 ... 0.3819 0.3552 0.3604
#     cloud_LW     (time) float64 -0.4466 -0.5926 0.2045 ... 1.907 1.624 0.3579
#     cloud_SW     (time) float64 1.475 1.971 1.961 3.428 ... 1.308 1.79 2.57
#     cloud_NET    (time) float64 1.029 1.378 2.165 2.083 ... 3.215 3.414 2.928
#     atmos_conv   (time) float64 0.7767 -2.595 -1.637 ... -3.318 -2.67 -1.16
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# IPSL-CM5B-LR
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 3.564 1.196 0.4558 -0.1559 ... 20.21 24.47 21.11
#     wv_LWAS      (time) float64 0.327 0.1819 -0.6906 ... 3.542 1.464 1.046
#     wv_LWCS      (time) float64 0.2458 0.1554 -0.9132 ... 4.533 1.925 1.317
#     wv_SWAS      (time) float64 0.0002043 0.0006486 -0.1152 ... 0.00932 0.0
#     wv_SWCS      (time) float64 0.0003024 -0.001559 -0.1362 ... 0.01186 0.0
#     wv_NETAS     (time) float64 0.3273 0.1825 -0.8058 ... 3.958 1.473 1.046
#     wv_NETCS     (time) float64 0.2461 0.1539 -1.049 0.167 ... 5.0 1.937 1.317
#     planck_LWAS  (time) float64 -8.432 -2.819 -0.9488 ... -52.72 -60.58 -50.78
#     lapse_LWAS   (time) float64 0.93 2.735 2.332 -0.5748 ... 23.32 30.22 22.56
#     albedo_SWAS  (time) float64 -0.0001879 -0.04799 -0.2828 ... 0.07206 0.0
#     albedo_SWCS  (time) float64 -0.0002202 -0.05908 -0.3215 ... 5.176 0.1166 0.0
#     cloud_LW     (time) float64 -0.004586 0.1509 0.4299 ... 8.816 4.815 3.678
#     cloud_SW     (time) float64 4.532e-05 -0.09753 -0.2269 ... -0.07392 0.0
#     cloud_NET    (time) float64 -0.004541 0.05335 0.203 ... 6.166 4.741 3.678
#     atmos_conv   (time) float64 -25.91 -21.54 -1.94 -2.103 ... 17.8 -5.47 -23.92
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.1954 0.428 0.3947 0.674 ... 3.135 3.206 3.161
#     wv_LWAS      (time) float64 -0.6935 0.2378 1.06 1.052 ... 7.36 7.149 6.99
#     wv_LWCS      (time) float64 -0.9445 0.2639 1.563 1.41 ... 9.938 9.787 9.848
#     wv_SWAS      (time) float64 -0.06799 0.07956 0.1902 ... 1.088 1.123 1.073
#     wv_SWCS      (time) float64 -0.01218 0.08643 0.06965 ... 0.425 0.5056 0.4311
#     wv_NETAS     (time) float64 -0.7615 0.3173 1.25 1.157 ... 8.447 8.272 8.064
#     wv_NETCS     (time) float64 -0.9567 0.3503 1.633 1.46 ... 10.36 10.29 10.28
#     planck_LWAS  (time) float64 -0.7133 -1.561 -1.423 ... -11.25 -11.55 -11.36
#     lapse_LWAS   (time) float64 0.5851 -0.212 -0.7678 ... -4.634 -4.466 -4.259
#     albedo_SWAS  (time) float64 0.1129 0.1744 0.166 ... 0.124 0.1478 0.1259
#     albedo_SWCS  (time) float64 0.1836 0.2733 0.2757 ... 0.1906 0.219 0.1908
#     cloud_LW     (time) float64 -0.4281 0.1063 1.869 ... 0.6975 0.6119 1.343
#     cloud_SW     (time) float64 3.056 1.312 -0.6212 1.251 ... 1.207 2.59 0.6232
#     cloud_NET    (time) float64 2.628 1.418 1.248 1.753 ... 1.905 3.202 1.966
#     atmos_conv   (time) float64 2.104 -0.02334 0.3131 ... 0.9833 1.435 -0.7016
# GFDL-ESM2G
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -3.123 1.088 4.277 0.8073 ... 14.54 18.43 17.29
#     wv_LWAS      (time) float64 0.0665 0.5397 0.8536 ... 3.101 2.098 1.442
#     wv_LWCS      (time) float64 0.1292 0.6226 0.797 0.6392 ... 3.792 2.609 1.655
#     wv_SWAS      (time) float64 -0.0001884 0.0188 0.4812 ... 0.3804 0.01368 0.0
#     wv_SWCS      (time) float64 -0.0002713 0.01817 0.56 ... 0.4102 0.01661 0.0
#     wv_NETAS     (time) float64 0.06632 0.5585 1.335 ... 3.481 2.111 1.442
#     wv_NETCS     (time) float64 0.1289 0.6407 1.357 1.023 ... 4.202 2.626 1.655
#     planck_LWAS  (time) float64 7.453 -2.341 -10.16 ... -37.31 -44.97 -40.51
#     lapse_LWAS   (time) float64 -1.488 -1.044 1.589 -1.606 ... 14.54 19.11 14.46
#     albedo_SWAS  (time) float64 0.0001916 0.02847 0.142 ... 3.403 0.09073 0.0
#     albedo_SWCS  (time) float64 7.312e-05 0.004138 -0.05337 ... 4.89 0.1246 0.0
#     cloud_LW     (time) float64 0.6679 0.5871 0.5184 ... 5.319 6.234 5.499
#     cloud_SW     (time) float64 -0.0003442 -0.01911 -0.1299 ... -0.002883 0.0
#     cloud_NET    (time) float64 0.6676 0.568 0.3885 ... 4.944 6.231 5.499
#     atmos_conv   (time) float64 15.84 15.46 5.38 ... -11.16 -8.349 -0.2156
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.09475 0.3643 0.5391 ... 3.662 3.602 3.515
#     wv_LWAS      (time) float64 -0.4803 0.1259 1.303 1.23 ... 9.073 8.884 9.055
#     wv_LWCS      (time) float64 -0.5907 0.1307 1.762 1.72 ... 12.18 11.88 12.17
#     wv_SWAS      (time) float64 -0.06284 -0.05586 0.1777 ... 1.366 1.28 1.331
#     wv_SWCS      (time) float64 -0.004764 -0.01503 0.08256 ... 0.5767 0.619
#     wv_NETAS     (time) float64 -0.5431 0.07001 1.481 1.42 ... 10.44 10.16 10.39
#     wv_NETCS     (time) float64 -0.5954 0.1157 1.845 1.844 ... 12.78 12.46 12.79
#     planck_LWAS  (time) float64 -0.3672 -1.334 -1.959 ... -13.18 -13.04 -12.7
#     lapse_LWAS   (time) float64 -0.008839 -0.2683 -0.989 ... -6.361 -5.78 -6.13
#     albedo_SWAS  (time) float64 0.04604 0.07454 0.06762 ... 0.0419 0.144 0.1521
#     albedo_SWCS  (time) float64 0.05296 0.09161 0.09419 ... 0.1091 0.2068 0.2201
#     cloud_LW     (time) float64 0.5583 0.9043 1.143 0.9786 ... 3.925 4.422 3.374
#     cloud_SW     (time) float64 2.147 1.114 0.03393 ... 0.6184 -0.6955 0.02894
#     cloud_NET    (time) float64 2.705 2.019 1.177 1.098 ... 4.543 3.727 3.403
#     atmos_conv   (time) float64 1.201 -1.265 -1.284 ... 0.7648 -7.027 -0.3188
# MIROC-ESM
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 1.332 0.2541 1.455 2.411 ... 16.79 20.0 22.01
#     wv_LWAS      (time) float64 -0.2354 -0.2751 -0.3923 ... 4.501 2.884 1.255
#     wv_LWCS      (time) float64 -0.2352 -0.2152 -0.3907 ... 5.609 3.527 1.52
#     wv_SWAS      (time) float64 -8.03e-05 -0.01808 -0.07852 ... 0.01599 0.0
#     wv_SWCS      (time) float64 -0.0001274 -0.01838 -0.09895 ... 0.01882 0.0
#     wv_NETAS     (time) float64 -0.2355 -0.2931 -0.4708 ... 4.986 2.9 1.255
#     wv_NETCS     (time) float64 -0.2353 -0.2335 -0.4896 ... 6.123 3.545 1.52
#     planck_LWAS  (time) float64 -3.094 -0.6404 -3.424 ... -43.19 -48.39 -51.16
#     lapse_LWAS   (time) float64 2.204 1.935 3.509 1.474 ... 12.32 16.37 19.01
#     albedo_SWAS  (time) float64 0.0003944 0.08755 0.6765 ... 3.278 0.08079 0.0
#     albedo_SWCS  (time) float64 0.000507 0.1208 0.8641 ... 4.362 0.09784 0.0
#     cloud_LW     (time) float64 0.8896 1.552 2.413 0.1157 ... 5.97 7.327 7.306
#     cloud_SW     (time) float64 -0.0005218 -0.08472 -0.4728 ... -0.0571 0.0
#     cloud_NET    (time) float64 0.8891 1.468 1.94 0.05877 ... 3.373 7.27 7.306
#     atmos_conv   (time) float64 -19.27 -19.4 -6.844 ... 8.788 -9.139 -21.62
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -0.07296 0.2083 0.3847 ... 5.83 5.79 5.904
#     wv_LWAS      (time) float64 -1.058 -1.076 0.007206 ... 12.82 13.34 13.26
#     wv_LWCS      (time) float64 -1.529 -1.549 0.03616 ... 17.42 17.88 17.56
#     wv_SWAS      (time) float64 -0.1977 -0.1972 -0.02046 ... 1.956 2.038 1.899
#     wv_SWCS      (time) float64 -0.07755 -0.07193 0.00841 ... 0.9464 0.8966
#     wv_NETAS     (time) float64 -1.255 -1.273 -0.01325 ... 14.77 15.38 15.15
#     wv_NETCS     (time) float64 -1.607 -1.621 0.04457 ... 18.24 18.83 18.46
#     planck_LWAS  (time) float64 0.32 -0.7451 -1.336 ... -21.07 -21.03 -21.34
#     lapse_LWAS   (time) float64 0.7007 0.9433 -0.1996 ... -8.622 -8.131 -8.099
#     albedo_SWAS  (time) float64 0.02963 0.04779 0.05365 ... 0.1468 0.201 0.2524
#     albedo_SWCS  (time) float64 0.04237 0.06788 0.08324 ... 0.2169 0.2824 0.3291
#     cloud_LW     (time) float64 -0.6499 -0.2066 0.19 ... 2.497 2.69 2.798
#     cloud_SW     (time) float64 5.337 5.415 3.293 3.873 ... 6.721 5.545 6.247
#     cloud_NET    (time) float64 4.687 5.208 3.483 3.391 ... 9.218 8.235 9.045
#     atmos_conv   (time) float64 -0.2188 -2.917 -3.518 ... -0.6801 -0.7032 -3.935
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# FGOALS-g2
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0490-01-16 12:00:00 ... 0639-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 1.5 1.785 1.071 3.207 ... 9.743 17.0 22.46 25.32
#     wv_LWAS      (time) float64 0.4063 0.3751 0.42 1.08 ... 3.276 1.866 1.046
#     wv_LWCS      (time) float64 0.5055 0.3841 0.5086 1.222 ... 4.081 2.399 1.224
#     wv_SWAS      (time) float64 0.000188 0.02478 0.02563 ... 0.4007 0.01429 0.0
#     wv_SWCS      (time) float64 0.0002469 0.03169 0.006214 ... 0.01702 0.0
#     wv_NETAS     (time) float64 0.4065 0.3999 0.4456 2.212 ... 3.676 1.88 1.046
#     wv_NETCS     (time) float64 0.5058 0.4158 0.5148 2.457 ... 4.51 2.416 1.224
#     planck_LWAS  (time) float64 -3.533 -4.258 -2.665 ... -43.76 -54.87 -59.8
#     lapse_LWAS   (time) float64 1.354 0.4445 1.108 1.46 ... 16.64 23.83 23.62
#     albedo_SWAS  (time) float64 9.518e-05 -0.007673 0.02793 ... 0.07127 0.0
#     albedo_SWCS  (time) float64 0.0001204 -0.01973 0.03105 ... 4.774 0.1024 0.0
#     cloud_LW     (time) float64 1.474 -0.6243 -0.2835 ... 5.427 3.143 1.261
#     cloud_SW     (time) float64 -0.000745 0.001993 -0.2523 ... -0.04182 0.0
#     cloud_NET    (time) float64 1.473 -0.6223 -0.5358 ... 3.937 3.102 1.261
#     atmos_conv   (time) float64 -9.429 0.8911 0.2765 ... -0.2563 -16.99 -10.11
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0490-01-16 12:00:00 ... 0639-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.475 0.6461 0.7962 0.842 ... 4.586 4.689 4.662
#     wv_LWAS      (time) float64 0.5399 1.397 1.313 1.79 ... 11.5 11.6 11.53
#     wv_LWCS      (time) float64 0.6062 1.681 1.771 2.267 ... 15.22 15.41 15.46
#     wv_SWAS      (time) float64 0.05625 0.1798 0.2366 ... 1.686 1.689 1.697
#     wv_SWCS      (time) float64 0.04634 0.1039 0.1284 ... 0.7471 0.7778 0.8013
#     wv_NETAS     (time) float64 0.5962 1.577 1.55 2.039 ... 13.19 13.29 13.23
#     wv_NETCS     (time) float64 0.6526 1.785 1.899 2.411 ... 15.97 16.19 16.26
#     planck_LWAS  (time) float64 -1.738 -2.332 -2.887 ... -16.59 -16.97 -16.86
#     lapse_LWAS   (time) float64 -0.192 -0.9794 -0.9899 ... -6.367 -6.553 -6.309
#     albedo_SWAS  (time) float64 0.04134 0.04477 -0.003848 ... 0.09859 0.1303
#     albedo_SWCS  (time) float64 0.03864 0.05134 -0.01631 ... 0.07595 0.135 0.171
#     cloud_LW     (time) float64 1.326 1.414 1.117 0.4463 ... 3.737 3.663 4.061
#     cloud_SW     (time) float64 -0.4113 -1.027 -0.2091 ... -0.5453 -1.202
#     cloud_NET    (time) float64 0.9146 0.3875 0.9077 ... 3.002 3.117 2.859
#     atmos_conv   (time) float64 -4.101 -1.193 -1.64 ... 0.2667 0.7121 -2.836
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# bcc-csm1-1
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0160-01-16 12:00:00 ... 0309-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -2.669 1.702 3.262 2.875 ... 15.62 22.49 22.4
#     wv_LWAS      (time) float64 -0.9381 0.2262 0.101 ... 2.857 1.752 1.115
#     wv_LWCS      (time) float64 -1.345 0.2864 -0.0866 0.147 ... 3.659 2.36 1.406
#     wv_SWAS      (time) float64 -0.0003523 -0.005662 0.1999 ... 0.01329 0.0
#     wv_SWCS      (time) float64 -0.0004278 -0.008724 0.2326 ... 0.01668 0.0
#     wv_NETAS     (time) float64 -0.9384 0.2205 0.3009 ... 3.231 1.765 1.115
#     wv_NETCS     (time) float64 -1.345 0.2776 0.146 1.01 ... 4.072 2.377 1.406
#     planck_LWAS  (time) float64 6.366 -3.869 -7.524 ... -40.18 -54.57 -53.16
#     lapse_LWAS   (time) float64 0.1635 1.572 2.927 2.665 ... 15.44 23.71 21.52
#     albedo_SWAS  (time) float64 -0.0001567 -0.03675 -0.145 ... 2.547 0.07308 0.0
#     albedo_SWCS  (time) float64 -0.0003377 -0.05755 -0.2944 ... 3.74 0.104 0.0
#     cloud_LW     (time) float64 0.9438 3.639 3.673 2.957 ... 8.406 15.04 7.809
#     cloud_SW     (time) float64 -0.001225 -0.0586 ... -0.08152 -0.0009595
#     cloud_NET    (time) float64 0.9425 3.58 3.099 0.2765 ... 6.039 14.96 7.808
#     atmos_conv   (time) float64 -27.74 -5.641 -4.465 ... -14.75 -6.784 36.93
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0160-01-16 12:00:00 ... 0309-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -0.002448 0.1381 0.2699 ... 4.043 4.016 4.002
#     wv_LWAS      (time) float64 -0.2996 -0.2717 0.1844 ... 8.745 8.871 8.503
#     wv_LWCS      (time) float64 -0.1656 -0.2233 0.1992 ... 11.81 11.93 11.74
#     wv_SWAS      (time) float64 0.01163 0.0008708 -0.007476 ... 1.396 1.324
#     wv_SWCS      (time) float64 0.01605 0.006467 -0.03852 ... 0.6465 0.5935
#     wv_NETAS     (time) float64 -0.288 -0.2708 0.1769 ... 10.13 10.27 9.827
#     wv_NETCS     (time) float64 -0.1496 -0.2168 0.1607 ... 12.39 12.58 12.33
#     planck_LWAS  (time) float64 0.01392 -0.4931 -0.9706 ... -14.52 -14.47 -14.36
#     lapse_LWAS   (time) float64 -0.5523 -0.6965 -0.2568 ... -4.563 -4.841 -5.525
#     albedo_SWAS  (time) float64 0.01697 0.06918 0.0199 ... 0.08685 0.09997
#     albedo_SWCS  (time) float64 0.03162 0.1083 0.04079 ... 0.08978 0.1345 0.15
#     cloud_LW     (time) float64 1.078 0.5661 0.3239 0.2449 ... 2.025 2.321 2.847
#     cloud_SW     (time) float64 -2.068 0.129 1.149 ... -0.112 -0.817 -1.622
#     cloud_NET    (time) float64 -0.9903 0.6951 1.473 1.453 ... 1.913 1.504 1.224
#     atmos_conv   (time) float64 -3.668 1.717 0.8959 ... -2.016 -1.968 0.6345
# BNU-ESM
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 4.496 2.171 2.181 3.424 ... 19.27 24.27 26.05
#     wv_LWAS      (time) float64 -0.1554 0.3145 -0.07072 ... 3.822 2.387 1.137
#     wv_LWCS      (time) float64 -0.1329 0.3539 -0.1148 ... 4.75 2.921 1.393
#     wv_SWAS      (time) float64 0.0001776 0.02071 0.07521 ... 0.4275 0.01637 0.0
#     wv_SWCS      (time) float64 0.0002565 0.02522 0.08678 ... 0.4614 0.0195 0.0
#     wv_NETAS     (time) float64 -0.1553 0.3352 0.004489 ... 4.249 2.404 1.137
#     wv_NETCS     (time) float64 -0.1326 0.3792 -0.028 1.782 ... 5.211 2.94 1.393
#     planck_LWAS  (time) float64 -10.76 -5.042 -5.13 ... -49.52 -58.65 -60.6
#     lapse_LWAS   (time) float64 2.536 2.096 2.487 2.499 ... 19.42 25.14 25.32
#     albedo_SWAS  (time) float64 8.738e-05 -0.02101 -0.08574 ... 4.401 0.1062 0.0
#     albedo_SWCS  (time) float64 0.00013 -0.005137 -0.03894 ... 6.216 0.1421 0.0
#     cloud_LW     (time) float64 -1.934 1.942 1.671 3.036 ... 10.71 10.73 11.23
#     cloud_SW     (time) float64 0.0002343 -0.06655 -0.3227 ... -0.09837 0.0
#     cloud_NET    (time) float64 -1.933 1.876 1.349 1.267 ... 7.4 10.63 11.23
#     atmos_conv   (time) float64 -5.815 -15.93 -10.09 ... -16.6 -20.32 4.867
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -0.03502 0.07854 0.1011 ... 4.389 4.364 4.252
#     wv_LWAS      (time) float64 -1.064 -1.145 -0.5119 ... 10.62 10.07 10.1
#     wv_LWCS      (time) float64 -0.9165 -1.322 -0.5256 ... 14.15 13.4 13.63
#     wv_SWAS      (time) float64 -0.08956 -0.05801 0.0005968 ... 1.598 1.542
#     wv_SWCS      (time) float64 -0.0649 -0.01131 0.005142 ... 0.8033 0.7387
#     wv_NETAS     (time) float64 -1.154 -1.203 -0.5113 ... 12.36 11.67 11.64
#     wv_NETCS     (time) float64 -0.9814 -1.334 -0.5205 ... 15.01 14.2 14.37
#     planck_LWAS  (time) float64 0.1458 -0.2938 -0.3973 ... -15.83 -15.77 -15.32
#     lapse_LWAS   (time) float64 -0.3178 0.1668 0.2765 ... -6.192 -5.865 -6.152
#     albedo_SWAS  (time) float64 0.08399 0.3053 0.2567 ... 0.9202 0.9744 0.9955
#     albedo_SWCS  (time) float64 0.1304 0.4283 0.3708 ... 1.089 1.054 1.098
#     cloud_LW     (time) float64 0.3742 -1.099 0.4558 ... 2.827 2.269 2.872
#     cloud_SW     (time) float64 -0.2897 0.7991 1.064 ... -2.46 -1.662 -3.493
#     cloud_NET    (time) float64 0.08456 -0.2997 1.52 ... 0.3665 0.6074 -0.6209
#     atmos_conv   (time) float64 -2.213 3.203 -4.662 ... 2.153 -0.2011 -0.6273
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# CanESM2
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.0762 -3.639 -0.1898 ... 14.33 21.18 24.08
#     wv_LWAS      (time) float64 0.05398 0.1677 -0.0295 ... 4.238 2.852 1.636
#     wv_LWCS      (time) float64 0.1708 0.3285 -0.07373 ... 5.333 3.395 1.924
#     wv_SWAS      (time) float64 -5.35e-05 -0.04407 -0.1299 ... 0.01769 0.0
#     wv_SWCS      (time) float64 -3.946e-05 -0.05921 -0.1672 ... 0.0213 0.0
#     wv_NETAS     (time) float64 0.05393 0.1236 -0.1594 ... 4.687 2.87 1.636
#     wv_NETCS     (time) float64 0.1707 0.2693 -0.2409 ... 5.803 3.417 1.924
#     planck_LWAS  (time) float64 -0.1488 8.52 0.452 ... -36.71 -51.49 -56.72
#     lapse_LWAS   (time) float64 -0.9626 -2.565 0.5318 0.699 ... 9.93 18.57 21.43
#     albedo_SWAS  (time) float64 -0.0002459 -0.05007 -0.2266 ... 2.13 0.05513 0.0
#     albedo_SWCS  (time) float64 -0.0004496 -0.09319 -0.2777 ... 2.92 0.07126 0.0
#     cloud_LW     (time) float64 0.2526 0.2378 1.106 0.5492 ... 10.29 7.945 8.15
#     cloud_SW     (time) float64 0.0006023 -0.116 ... -0.07583 -8.204e-06
#     cloud_NET    (time) float64 0.2532 0.1218 1.085 1.062 ... 7.511 7.87 8.15
#     atmos_conv   (time) float64 12.59 -9.599 -10.55 ... 12.32 -3.638 -38.42
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.3272 0.5124 0.5915 ... 5.248 5.325 5.388
#     wv_LWAS      (time) float64 -0.8557 -0.8598 -0.2605 ... 12.08 11.15 11.52
#     wv_LWCS      (time) float64 -1.277 -1.029 -0.05703 ... 16.06 14.81 15.14
#     wv_SWAS      (time) float64 -0.1211 -0.1326 -0.03724 ... 1.931 1.702 1.627
#     wv_SWCS      (time) float64 -0.02314 -0.04772 -0.02144 ... 0.7602 0.768
#     wv_NETAS     (time) float64 -0.9768 -0.9924 -0.2977 ... 14.01 12.85 13.15
#     wv_NETCS     (time) float64 -1.3 -1.077 -0.07847 0.6728 ... 16.96 15.57 15.9
#     planck_LWAS  (time) float64 -1.223 -1.854 -2.134 ... -18.89 -19.22 -19.43
#     lapse_LWAS   (time) float64 0.4387 -0.2637 -0.6285 ... -6.859 -6.989 -6.631
#     albedo_SWAS  (time) float64 0.04845 0.006431 0.01477 ... 0.1622 0.1221 0.152
#     albedo_SWCS  (time) float64 0.07389 0.005879 0.03041 ... 0.2216 0.157 0.1891
#     cloud_LW     (time) float64 -0.3447 -0.1971 -0.1535 ... 6.595 5.146 5.613
#     cloud_SW     (time) float64 4.059 4.349 3.699 1.238 ... -0.1188 3.534 2.963
#     cloud_NET    (time) float64 3.714 4.152 3.545 1.328 ... 6.476 8.68 8.575
#     atmos_conv   (time) float64 -1.4 -2.284 -3.251 ... -1.783 0.1636 -3.946
# CCSM4
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 2.048 -0.869 2.194 1.582 ... 16.21 22.27 21.74
#     wv_LWAS      (time) float64 0.03627 -0.27 0.1348 ... 3.062 2.357 1.157
#     wv_LWCS      (time) float64 0.05164 -0.3591 0.1699 ... 3.73 2.799 1.313
#     wv_SWAS      (time) float64 0.0001579 -0.01509 0.2025 ... 0.3069 0.01424 0.0
#     wv_SWCS      (time) float64 0.0002222 -0.01867 0.2202 ... 0.3268 0.01684 0.0
#     wv_NETAS     (time) float64 0.03643 -0.2851 0.3373 ... 3.369 2.372 1.157
#     wv_NETCS     (time) float64 0.05186 -0.3777 0.3901 ... 4.056 2.816 1.313
#     planck_LWAS  (time) float64 -4.724 2.017 -5.194 ... -41.46 -53.67 -50.34
#     lapse_LWAS   (time) float64 1.501 0.4627 1.9 1.332 ... 16.41 22.55 21.36
#     albedo_SWAS  (time) float64 0.0003499 0.005985 0.1616 ... 3.683 0.08642 0.0
#     albedo_SWCS  (time) float64 0.0004203 0.01198 0.1716 ... 5.169 0.1125 0.0
#     cloud_LW     (time) float64 -0.6696 -0.5704 0.3561 ... 5.582 6.79 6.937
#     cloud_SW     (time) float64 0.0003263 0.003441 -0.0176 ... -0.04277 0.0
#     cloud_NET    (time) float64 -0.6693 -0.567 0.3385 ... 3.665 6.748 6.937
#     atmos_conv   (time) float64 -23.84 -19.2 -0.181 ... -3.565 -11.25 -18.01
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.7138 0.7413 0.8 0.8837 ... 3.941 3.886 3.949
#     wv_LWAS      (time) float64 0.1812 0.6956 0.1818 0.7794 ... 8.525 8.275 7.77
#     wv_LWCS      (time) float64 0.2311 0.9489 0.3465 1.255 ... 11.32 11.02 10.62
#     wv_SWAS      (time) float64 0.06685 0.1786 0.1469 ... 1.324 1.298 1.221
#     wv_SWCS      (time) float64 0.04136 0.1294 0.1161 ... 0.5824 0.62 0.5702
#     wv_NETAS     (time) float64 0.2481 0.8742 0.3287 0.9204 ... 9.849 9.574 8.99
#     wv_NETCS     (time) float64 0.2724 1.078 0.4626 1.322 ... 11.9 11.64 11.19
#     planck_LWAS  (time) float64 -2.566 -2.662 -2.896 ... -14.27 -14.13 -14.27
#     lapse_LWAS   (time) float64 0.5059 -0.6438 -0.1211 ... -4.307 -4.61 -4.546
#     albedo_SWAS  (time) float64 -0.002932 0.0275 0.04709 ... 0.1183 0.1144
#     albedo_SWCS  (time) float64 -0.002613 0.02608 0.05967 ... 0.155 0.1659 0.157
#     cloud_LW     (time) float64 0.07489 1.253 -1.489 ... 2.921 2.289 1.917
#     cloud_SW     (time) float64 3.912 1.206 4.277 2.445 ... 0.3947 -1.233 0.9156
#     cloud_NET    (time) float64 3.987 2.459 2.788 3.0 ... 3.316 1.056 2.833
#     atmos_conv   (time) float64 0.2377 -7.57 1.941 ... -3.442 0.7668 -2.526
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# CSIRO-Mk3-6-0
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 1.535 -1.126 0.2618 2.208 ... 17.0 19.1 18.62
#     wv_LWAS      (time) float64 -0.2149 -0.3986 0.1061 ... 4.377 2.527 1.724
#     wv_LWCS      (time) float64 -0.239 -0.5876 0.1502 ... 5.305 3.194 2.096
#     wv_SWAS      (time) float64 -2.35e-05 -0.04073 0.08708 ... 0.01405 0.0
#     wv_SWCS      (time) float64 -1.821e-05 -0.05558 0.06731 ... 0.01694 0.0
#     wv_NETAS     (time) float64 -0.2149 -0.4394 0.1932 ... 4.807 2.541 1.724
#     wv_NETCS     (time) float64 -0.239 -0.6432 0.2175 ... 5.772 3.211 2.096
#     planck_LWAS  (time) float64 -3.692 2.834 -0.5875 ... -44.47 -47.16 -44.64
#     lapse_LWAS   (time) float64 1.079 -0.9359 -1.027 1.914 ... 17.02 19.85 15.94
#     albedo_SWAS  (time) float64 4.438e-05 0.00666 0.06888 ... 3.466 0.0876 0.0
#     albedo_SWCS  (time) float64 9.661e-05 -0.001995 0.01391 ... 5.403 0.1273 0.0
#     cloud_LW     (time) float64 0.01687 -0.6966 0.3034 ... 4.909 6.719 4.57
#     cloud_SW     (time) float64 0.001028 0.02527 -0.03666 ... -0.01639 0.0
#     cloud_NET    (time) float64 0.0179 -0.6713 0.2667 ... 3.979 6.703 4.57
#     atmos_conv   (time) float64 2.496 -1.392 -0.4177 ... -4.444 -13.58 20.82
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.1038 0.2277 0.3143 ... 5.566 5.559 5.639
#     wv_LWAS      (time) float64 -0.7911 -0.9803 -0.1572 ... 11.09 11.2 11.23
#     wv_LWCS      (time) float64 -1.246 -1.188 -0.1243 ... 15.03 14.92 15.11
#     wv_SWAS      (time) float64 -0.1168 -0.1498 0.01321 ... 1.695 1.657 1.655
#     wv_SWCS      (time) float64 -0.02737 -0.06447 0.03179 ... 0.7378 0.7473
#     wv_NETAS     (time) float64 -0.908 -1.13 -0.144 0.5419 ... 12.78 12.85 12.88
#     wv_NETCS     (time) float64 -1.273 -1.253 -0.09246 ... 15.74 15.66 15.86
#     planck_LWAS  (time) float64 -0.3919 -0.8606 -1.184 ... -20.06 -20.07 -20.33
#     lapse_LWAS   (time) float64 0.6269 0.3887 0.2166 ... -6.327 -6.272 -6.031
#     albedo_SWAS  (time) float64 -0.02855 -0.00783 0.009795 ... 0.01674 0.007048
#     albedo_SWCS  (time) float64 -0.03383 -0.005729 0.01036 ... 0.0171 0.01276
#     cloud_LW     (time) float64 -0.1185 -0.1476 0.5005 ... 0.3954 0.6175 0.3208
#     cloud_SW     (time) float64 2.896 2.755 2.027 2.034 ... 8.723 8.117 7.551
#     cloud_NET    (time) float64 2.777 2.607 2.527 2.855 ... 9.119 8.734 7.872
#     atmos_conv   (time) float64 0.5998 -2.259 -2.538 ... -3.46 -4.325 -1.477
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# FGOALS-s2
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 3.674 3.584 1.75 3.012 ... 21.16 26.13 25.4
#     wv_LWAS      (time) float64 -0.1955 -0.8344 0.2689 ... 3.55 2.568 0.7803
#     wv_LWCS      (time) float64 -0.1278 -1.054 0.3798 ... 4.311 2.995 0.9209
#     wv_SWAS      (time) float64 0.0001857 -0.0008036 0.06053 ... 0.0169 0.0
#     wv_SWCS      (time) float64 0.0002284 0.004949 0.05053 ... 0.02063 0.0
#     wv_NETAS     (time) float64 -0.1954 -0.8352 0.3294 ... 3.949 2.585 0.7803
#     wv_NETCS     (time) float64 -0.1276 -1.049 0.4303 ... 4.751 3.015 0.9209
#     planck_LWAS  (time) float64 -8.643 -8.088 -4.195 ... -55.05 -63.7 -59.22
#     lapse_LWAS   (time) float64 3.159 4.76 2.109 1.221 ... 23.13 27.73 26.28
#     albedo_SWAS  (time) float64 -4.456e-06 -0.01589 -0.1516 ... 4.062 0.1069 0.0
#     albedo_SWCS  (time) float64 -3.132e-05 -0.03553 -0.1812 ... 6.038 0.1483 0.0
#     cloud_LW     (time) float64 1.823 -0.2566 0.6627 ... 3.334 5.056 6.716
#     cloud_SW     (time) float64 -0.001043 0.02248 -0.3382 ... -0.03465 0.0
#     cloud_NET    (time) float64 1.822 -0.2341 0.3245 ... 1.579 5.021 6.716
#     atmos_conv   (time) float64 -10.53 -10.38 8.435 ... -9.827 -36.96 -60.88
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.2229 0.3885 0.5499 ... 4.506 4.481 4.414
#     wv_LWAS      (time) float64 0.4145 0.1983 1.089 1.524 ... 11.23 10.68 10.76
#     wv_LWCS      (time) float64 0.2713 0.6118 1.733 2.13 ... 15.35 14.8 15.33
#     wv_SWAS      (time) float64 0.005982 0.137 0.2536 ... 1.891 1.797 1.844
#     wv_SWCS      (time) float64 0.05428 0.05517 0.1285 ... 0.8186 0.7466 0.8288
#     wv_NETAS     (time) float64 0.4204 0.3353 1.343 1.818 ... 13.12 12.48 12.6
#     wv_NETCS     (time) float64 0.3255 0.667 1.862 2.273 ... 16.17 15.55 16.16
#     planck_LWAS  (time) float64 -0.8202 -1.422 -2.037 ... -16.31 -16.19 -15.93
#     lapse_LWAS   (time) float64 -0.1654 -0.112 -0.7192 ... -6.121 -6.774 -7.219
#     albedo_SWAS  (time) float64 -0.002393 0.05329 0.02535 ... 0.1416 0.199
#     albedo_SWCS  (time) float64 -0.009967 0.07393 0.02885 ... 0.2177 0.2912
#     cloud_LW     (time) float64 0.9262 0.5477 1.379 0.9088 ... 3.923 3.573 4.311
#     cloud_SW     (time) float64 -0.6938 1.808 -0.531 ... -7.223 -4.309 -6.619
#     cloud_NET    (time) float64 0.2324 2.356 0.8485 ... -3.3 -0.7353 -2.308
#     atmos_conv   (time) float64 0.08758 -2.046 -3.789 ... -0.8858 -3.362 -4.851
# GFDL-CM3
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -3.056 -5.099 4.284 -0.2474 ... 15.7 21.24 25.26
#     wv_LWAS      (time) float64 -0.2604 -0.6884 0.7979 ... 3.743 2.445 1.424
#     wv_LWCS      (time) float64 -0.2976 -0.7529 0.9416 ... 4.581 2.959 1.746
#     wv_SWAS      (time) float64 -0.0002346 -0.06108 0.4238 ... 0.01709 0.0
#     wv_SWCS      (time) float64 -0.0003301 -0.07461 0.4875 ... 0.02094 0.0
#     wv_NETAS     (time) float64 -0.2607 -0.7495 1.222 ... 4.184 2.463 1.424
#     wv_NETCS     (time) float64 -0.2979 -0.8275 1.429 ... 5.062 2.98 1.746
#     planck_LWAS  (time) float64 7.301 12.02 -10.27 ... -40.44 -51.63 -59.12
#     lapse_LWAS   (time) float64 -1.656 -3.134 1.319 -0.1405 ... 12.05 18.9 22.0
#     albedo_SWAS  (time) float64 -0.0008092 -0.1078 -0.7094 ... 2.701 0.09147 0.0
#     albedo_SWCS  (time) float64 -0.0009613 -0.1809 -0.9922 ... 3.547 0.1126 0.0
#     cloud_LW     (time) float64 0.1388 0.1491 1.526 0.9707 ... 7.06 14.26 17.73
#     cloud_SW     (time) float64 -0.00151 -0.002628 ... -0.03667 -4.226e-06
#     cloud_NET    (time) float64 0.1373 0.1464 1.347 1.577 ... 6.035 14.22 17.73
#     atmos_conv   (time) float64 14.99 -2.347 18.46 ... -23.75 -34.11 -22.85
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -0.4112 -0.2711 -0.1776 ... 4.959 4.873 4.652
#     wv_LWAS      (time) float64 -2.426 -1.3 -0.3439 ... 10.59 10.24 10.98
#     wv_LWCS      (time) float64 -3.029 -1.775 -0.7191 ... 14.03 13.62 14.53
#     wv_SWAS      (time) float64 -0.3502 -0.2154 -0.003552 ... 1.62 1.529 1.615
#     wv_SWCS      (time) float64 -0.1825 -0.08798 0.09399 ... 0.7052 0.7854
#     wv_NETAS     (time) float64 -2.776 -1.516 -0.3474 ... 12.21 11.77 12.6
#     wv_NETCS     (time) float64 -3.212 -1.863 -0.6251 ... 14.78 14.32 15.32
#     planck_LWAS  (time) float64 1.584 1.036 0.6636 ... -17.78 -17.4 -16.63
#     lapse_LWAS   (time) float64 1.449 1.022 0.73 ... -8.361 -6.937 -6.357
#     albedo_SWAS  (time) float64 -0.04555 -0.03823 -0.0216 ... 0.3349 0.3381
#     albedo_SWCS  (time) float64 -0.05889 -0.04477 -0.03548 ... 0.4502 0.4625
#     cloud_LW     (time) float64 -0.8991 -0.7827 1.166 ... 1.435 2.515 3.539
#     cloud_SW     (time) float64 0.9063 1.052 0.123 0.1962 ... 5.13 3.643 3.53
#     cloud_NET    (time) float64 0.007257 0.2696 1.289 ... 6.565 6.158 7.069
#     atmos_conv   (time) float64 -2.155 0.003503 -2.1 ... 1.283 -0.7506 -3.239
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# inmcm4
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 2090-01-16 12:00:00 ... 2239-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 1.801 -1.615 -0.5602 1.725 ... 9.001 12.21 11.2
#     wv_LWAS      (time) float64 0.5843 0.3078 -0.5366 ... 1.68 0.4335 0.454
#     wv_LWCS      (time) float64 0.7371 0.3906 -0.6122 ... 2.13 0.5769 0.5619
#     wv_SWAS      (time) float64 0.000214 -0.008945 -0.08228 ... 0.006393 0.0
#     wv_SWCS      (time) float64 0.0002743 -0.01419 -0.08531 ... 0.008359 0.0
#     wv_NETAS     (time) float64 0.5846 0.2988 -0.6188 ... 1.87 0.4399 0.454
#     wv_NETCS     (time) float64 0.7373 0.3764 -0.6975 ... 2.332 0.5852 0.5619
#     planck_LWAS  (time) float64 -4.1 3.863 1.371 -4.255 ... -23.24 -29.67 -26.48
#     lapse_LWAS   (time) float64 0.622 -2.811 -0.02684 1.651 ... 9.314 14.3 11.1
#     albedo_SWAS  (time) float64 9.1e-06 -0.01694 -0.02576 ... 2.054 0.04518 0.0
#     albedo_SWCS  (time) float64 -8.312e-05 -0.04471 -0.2347 ... 0.05947 0.0
#     cloud_LW     (time) float64 0.5376 0.5387 0.1171 0.773 ... 4.096 3.563 2.775
#     cloud_SW     (time) float64 0.00255 0.07102 -0.09618 ... -0.009026 0.0
#     cloud_NET    (time) float64 0.5402 0.6097 0.02093 ... 3.581 3.554 2.775
#     atmos_conv   (time) float64 37.78 6.693 -3.213 ... -5.761 -21.48 -16.97
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 2090-01-16 12:00:00 ... 2239-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.3861 0.4641 0.4604 ... 2.691 2.584 2.709
#     wv_LWAS      (time) float64 0.3506 0.06155 0.4449 1.113 ... 6.008 5.19 5.409
#     wv_LWCS      (time) float64 0.2486 0.03034 0.5993 ... 8.193 7.057 7.547
#     wv_SWAS      (time) float64 0.02706 -0.04005 0.02548 ... 0.961 0.6962 0.8208
#     wv_SWCS      (time) float64 0.04458 0.0006557 0.02488 ... 0.2831 0.3552
#     wv_NETAS     (time) float64 0.3777 0.0215 0.4704 1.31 ... 6.969 5.887 6.23
#     wv_NETCS     (time) float64 0.2932 0.031 0.6241 1.684 ... 8.622 7.34 7.903
#     planck_LWAS  (time) float64 -1.374 -1.682 -1.669 ... -9.736 -9.342 -9.739
#     lapse_LWAS   (time) float64 -0.1737 -0.6241 -0.7705 ... -3.53 -3.743 -3.431
#     albedo_SWAS  (time) float64 -0.01965 0.01845 -0.01757 ... 0.06146 0.1068
#     albedo_SWCS  (time) float64 -0.01037 0.03295 -0.01625 ... 0.07773 0.1303
#     cloud_LW     (time) float64 1.074 1.188 1.187 1.331 ... 2.074 1.668 1.486
#     cloud_SW     (time) float64 -0.3724 0.3222 0.2018 ... -0.3579 -0.2966 -1.003
#     cloud_NET    (time) float64 0.7019 1.511 1.388 1.219 ... 1.716 1.372 0.4833
#     atmos_conv   (time) float64 0.7278 -0.4764 -0.6901 ... -0.8356 -5.772
# IPSL-CM5A-LR
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 1.593 2.596 1.964 2.552 ... 16.7 22.25 17.16
#     wv_LWAS      (time) float64 -0.3719 0.1708 0.09615 ... 3.861 3.221 1.03
#     wv_LWCS      (time) float64 -0.5776 0.2403 0.1209 ... 4.756 3.896 1.376
#     wv_SWAS      (time) float64 5.875e-05 0.02342 -0.08803 ... 0.4177 0.0178 0.0
#     wv_SWCS      (time) float64 0.0001194 0.0292 -0.08361 ... 0.4489 0.02138 0.0
#     wv_NETAS     (time) float64 -0.3718 0.1942 0.008126 ... 4.279 3.239 1.03
#     wv_NETCS     (time) float64 -0.5775 0.2695 0.0373 ... 5.205 3.918 1.376
#     planck_LWAS  (time) float64 -3.781 -6.113 -4.843 ... -42.97 -54.55 -41.1
#     lapse_LWAS   (time) float64 3.831 2.58 1.682 2.13 ... 15.65 20.68 16.61
#     albedo_SWAS  (time) float64 -0.0006148 0.01643 0.3486 ... 2.522 0.05236 0.0
#     albedo_SWCS  (time) float64 -0.0004954 0.07315 0.7855 ... 3.736 0.07731 0.0
#     cloud_LW     (time) float64 0.5096 1.897 -1.696 0.6956 ... 8.6 11.32 6.016
#     cloud_SW     (time) float64 -0.002006 -0.07662 0.8376 ... -0.06615 0.0
#     cloud_NET    (time) float64 0.5076 1.82 -0.8587 0.2019 ... 6.431 11.26 6.016
#     atmos_conv   (time) float64 -17.66 2.173 4.618 ... -4.932 0.1911 -21.47
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.5767 0.8802 1.007 1.227 ... 5.721 5.649 5.597
#     wv_LWAS      (time) float64 0.406 1.93 2.197 2.668 ... 13.73 13.83 13.35
#     wv_LWCS      (time) float64 0.482 2.504 2.792 3.42 ... 18.63 18.59 18.21
#     wv_SWAS      (time) float64 -0.06042 0.2098 0.2167 ... 2.215 2.164 2.053
#     wv_SWCS      (time) float64 -0.02429 0.106 0.08417 ... 1.009 0.9763 0.9174
#     wv_NETAS     (time) float64 0.3456 2.14 2.414 2.958 ... 15.95 15.99 15.4
#     wv_NETCS     (time) float64 0.4578 2.61 2.876 3.545 ... 19.64 19.56 19.12
#     planck_LWAS  (time) float64 -2.075 -3.164 -3.629 ... -20.65 -20.41 -20.19
#     lapse_LWAS   (time) float64 -0.3173 -1.417 -1.472 ... -8.536 -8.561 -8.585
#     albedo_SWAS  (time) float64 0.04976 0.08204 0.06968 ... 0.1254 0.1166 0.1184
#     albedo_SWCS  (time) float64 0.0779 0.116 0.09868 ... 0.1765 0.1667 0.1687
#     cloud_LW     (time) float64 -0.6959 0.5985 0.4693 ... 1.801 2.179 2.377
#     cloud_SW     (time) float64 4.118 2.674 4.052 4.135 ... 8.565 8.374 7.853
#     cloud_NET    (time) float64 3.422 3.273 4.521 5.022 ... 10.37 10.55 10.23
#     atmos_conv   (time) float64 -3.155 -4.071 -1.017 ... -3.461 -2.197 -0.8467
# MIROC5
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 2100-01-16 12:00:00 ... 2249-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 2.235 2.321 4.667 4.311 ... 18.71 23.66 24.95
#     wv_LWAS      (time) float64 -0.04185 -0.2471 0.401 ... 2.692 1.765 0.08544
#     wv_LWCS      (time) float64 0.03971 -0.1834 0.4192 ... 3.441 2.196 0.3265
#     wv_SWAS      (time) float64 -0.0001301 -0.02258 0.2973 ... 0.01323 0.0
#     wv_SWCS      (time) float64 -0.0002208 -0.024 0.3513 ... 0.4922 0.01676 0.0
#     wv_NETAS     (time) float64 -0.04198 -0.2696 0.6983 ... 3.115 1.779 0.08544
#     wv_NETCS     (time) float64 0.03949 -0.2074 0.7705 ... 3.933 2.213 0.3265
#     planck_LWAS  (time) float64 -5.441 -5.505 -11.24 ... -48.87 -57.9 -59.13
#     lapse_LWAS   (time) float64 2.075 2.146 3.386 3.417 ... 20.44 25.11 26.5
#     albedo_SWAS  (time) float64 -0.0002663 0.01494 0.2928 ... 4.294 0.1069 0.0
#     albedo_SWCS  (time) float64 -0.0002658 0.04442 0.4974 ... 6.091 0.1422 0.0
#     cloud_LW     (time) float64 0.3763 0.8314 0.9532 ... 4.999 5.456 6.228
#     cloud_SW     (time) float64 -0.0004022 -0.003815 -0.02713 ... -0.01909 0.0
#     cloud_NET    (time) float64 0.3759 0.8276 0.9261 1.005 ... 3.862 5.437 6.228
#     atmos_conv   (time) float64 8.918 2.449 2.447 4.677 ... -13.86 -17.48 -20.76
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 2100-01-16 12:00:00 ... 2249-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.3297 0.4631 0.5978 0.6719 ... 3.544 3.485 3.46
#     wv_LWAS      (time) float64 0.1223 0.3221 0.5555 ... 7.777 7.566 7.243
#     wv_LWCS      (time) float64 0.04286 0.2088 0.8023 ... 10.31 10.43 9.972
#     wv_SWAS      (time) float64 -0.005622 -0.00251 0.07438 ... 1.236 1.211 1.154
#     wv_SWCS      (time) float64 0.0302 0.03019 0.0571 ... 0.6117 0.5558 0.5237
#     wv_NETAS     (time) float64 0.1167 0.3196 0.6299 1.103 ... 9.013 8.777 8.397
#     wv_NETCS     (time) float64 0.07307 0.239 0.8594 1.456 ... 10.92 10.98 10.5
#     planck_LWAS  (time) float64 -1.135 -1.678 -2.158 ... -12.83 -12.65 -12.51
#     lapse_LWAS   (time) float64 -0.2279 -0.3163 -0.6759 ... -4.787 -5.223 -4.087
#     albedo_SWAS  (time) float64 0.02106 0.00415 0.009945 ... 0.1056 0.1245
#     albedo_SWCS  (time) float64 0.03423 0.02533 0.03142 ... 0.1491 0.1533 0.1733
#     cloud_LW     (time) float64 -0.9175 -1.226 -0.5304 ... 0.2221 -0.1299
#     cloud_SW     (time) float64 1.98 2.648 2.212 1.454 ... 0.3869 -0.2233 2.123
#     cloud_NET    (time) float64 1.063 1.422 1.682 ... 0.007655 -0.001198 1.994
#     atmos_conv   (time) float64 -2.317 -1.063 -1.206 ... -1.42 -2.408 2.022
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# MPI-ESM-LR
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -0.7869 0.8366 -0.6618 ... 15.6 20.96 23.99
#     wv_LWAS      (time) float64 -0.249 -0.4973 -0.03693 ... 4.04 2.791 1.878
#     wv_LWCS      (time) float64 -0.3525 -0.5609 -0.12 ... 5.015 3.444 2.237
#     wv_SWAS      (time) float64 -0.0001578 -0.02942 -0.1746 ... 0.0175 0.0
#     wv_SWCS      (time) float64 -0.0002057 -0.03737 -0.2075 ... 0.02133 0.0
#     wv_NETAS     (time) float64 -0.2492 -0.5267 -0.2115 ... 4.483 2.808 1.878
#     wv_NETCS     (time) float64 -0.3527 -0.5983 -0.3275 ... 5.489 3.465 2.237
#     planck_LWAS  (time) float64 1.945 -1.94 1.707 ... -39.92 -51.01 -56.02
#     lapse_LWAS   (time) float64 -0.08791 0.4681 -1.11 ... 12.07 18.52 18.54
#     albedo_SWAS  (time) float64 -0.0002409 -0.04976 -0.3404 ... 3.545 0.1328 0.0
#     albedo_SWCS  (time) float64 -0.0003252 -0.06433 -0.4545 ... 4.865 0.1673 0.0
#     cloud_LW     (time) float64 -0.4663 -1.295 -0.1598 ... 9.343 10.46 12.1
#     cloud_SW     (time) float64 0.002224 0.007158 0.3885 ... -0.07626 -0.001621
#     cloud_NET    (time) float64 -0.464 -1.288 0.2287 ... 6.828 10.38 12.1
#     atmos_conv   (time) float64 12.77 7.557 -9.121 ... 2.808 -14.81 -30.66
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.3012 0.5307 0.7224 ... 5.414 5.371 5.238
#     wv_LWAS      (time) float64 -1.344 -0.2669 0.09052 ... 12.9 12.31 11.99
#     wv_LWCS      (time) float64 -1.905 -0.42 -0.03461 ... 17.57 16.74 16.44
#     wv_SWAS      (time) float64 -0.193 -0.05483 -0.01293 ... 2.097 1.932 1.795
#     wv_SWCS      (time) float64 -0.03123 -0.006327 0.008591 ... 0.8867 0.7829
#     wv_NETAS     (time) float64 -1.537 -0.3217 0.07759 ... 15.0 14.24 13.78
#     wv_NETCS     (time) float64 -1.936 -0.4263 -0.02602 ... 18.48 17.62 17.22
#     planck_LWAS  (time) float64 -1.106 -1.967 -2.649 ... -19.44 -19.36 -18.82
#     lapse_LWAS   (time) float64 1.684 0.8959 0.2229 ... -7.75 -7.755 -8.389
#     albedo_SWAS  (time) float64 0.06958 0.1035 0.1337 ... 0.06658 0.04277
#     albedo_SWCS  (time) float64 0.08278 0.1341 0.1732 ... -0.01807 -0.07863
#     cloud_LW     (time) float64 -0.5103 0.008705 -0.336 ... 3.911 3.116 3.64
#     cloud_SW     (time) float64 4.324 4.64 3.11 4.416 ... 3.176 4.138 2.192
#     cloud_NET    (time) float64 3.814 4.649 2.774 4.557 ... 7.087 7.253 5.832
#     atmos_conv   (time) float64 0.5753 -1.012 1.603 ... -0.7803 -2.083 0.1435
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# MPI-ESM-P
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 2.584 4.885 3.957 3.479 ... 14.72 19.8 22.57
#     wv_LWAS      (time) float64 0.2002 0.3035 0.4831 ... 4.422 2.563 1.332
#     wv_LWCS      (time) float64 0.2688 0.4196 0.5333 0.8051 ... 5.376 3.09 1.632
#     wv_SWAS      (time) float64 0.0001403 0.0465 0.3098 ... 0.4453 0.01593 0.0
#     wv_SWCS      (time) float64 0.0001108 0.0605 0.3599 ... 0.4733 0.01903 0.0
#     wv_NETAS     (time) float64 0.2004 0.35 0.7929 1.63 ... 4.867 2.579 1.332
#     wv_NETCS     (time) float64 0.2689 0.4801 0.8932 1.909 ... 5.849 3.109 1.632
#     planck_LWAS  (time) float64 -6.018 -11.37 -9.592 ... -37.71 -48.03 -52.76
#     lapse_LWAS   (time) float64 3.267 2.933 1.904 2.025 ... 9.86 17.34 19.32
#     albedo_SWAS  (time) float64 0.0003005 0.01564 0.6681 ... 3.286 0.1099 0.0
#     albedo_SWCS  (time) float64 0.0003452 0.02953 0.9183 ... 4.485 0.1368 0.0
#     cloud_LW     (time) float64 2.345 0.7447 1.394 2.246 ... 7.745 10.83 10.68
#     cloud_SW     (time) float64 -0.001839 -0.05069 ... -0.07153 -0.002046
#     cloud_NET    (time) float64 2.343 0.694 1.45 0.4476 ... 4.889 10.76 10.68
#     atmos_conv   (time) float64 16.55 22.1 -6.559 2.234 ... -1.319 -17.73 -18.17
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1850-01-16 12:00:00 ... 1999-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.6303 0.6774 0.9147 1.045 ... 5.43 5.572 5.455
#     wv_LWAS      (time) float64 -0.02921 -0.1483 0.7508 ... 12.01 12.33 12.83
#     wv_LWCS      (time) float64 -0.1028 0.02073 1.024 ... 16.11 16.44 17.38
#     wv_SWAS      (time) float64 -0.02983 0.01301 0.06891 ... 1.946 1.91 1.96
#     wv_SWCS      (time) float64 0.0209 0.003039 0.02207 ... 0.8732 0.8851 0.8924
#     wv_NETAS     (time) float64 -0.05903 -0.1353 0.8197 ... 13.96 14.24 14.79
#     wv_NETCS     (time) float64 -0.08194 0.02377 1.046 ... 16.98 17.32 18.27
#     planck_LWAS  (time) float64 -2.287 -2.478 -3.305 ... -19.61 -20.15 -19.59
#     lapse_LWAS   (time) float64 0.9225 -0.002264 0.1086 ... -7.171 -7.105 -7.831
#     albedo_SWAS  (time) float64 0.1078 0.1455 0.06823 ... 0.1663 0.1877 0.208
#     albedo_SWCS  (time) float64 0.1171 0.1858 0.08662 ... 0.2441 0.2627 0.2742
#     cloud_LW     (time) float64 0.8222 -0.3014 0.01923 ... 2.234 3.124 3.786
#     cloud_SW     (time) float64 4.724 4.562 5.075 3.924 ... 6.884 5.651 5.636
#     cloud_NET    (time) float64 5.547 4.26 5.095 4.622 ... 9.119 8.775 9.422
#     atmos_conv   (time) float64 -2.628 -0.4706 -3.805 ... -0.7477 -4.618 -3.074
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# MRI-CGCM3
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1851-01-16 12:00:00 ... 2000-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 1.154 4.701 3.268 4.693 ... 17.6 24.18 22.38
#     wv_LWAS      (time) float64 0.4097 -0.14 0.3209 0.2253 ... 2.62 1.725 0.9611
#     wv_LWCS      (time) float64 0.5212 -0.1436 0.4022 ... 3.356 2.164 1.27
#     wv_SWAS      (time) float64 7.596e-05 0.01101 0.2286 ... 0.3201 0.01359 0.0
#     wv_SWCS      (time) float64 5.778e-05 0.01639 0.2592 ... 0.3437 0.01687 0.0
#     wv_NETAS     (time) float64 0.4098 -0.129 0.5495 1.041 ... 2.94 1.738 0.9611
#     wv_NETCS     (time) float64 0.5213 -0.1272 0.6614 1.256 ... 3.7 2.181 1.27
#     planck_LWAS  (time) float64 -2.743 -11.0 -7.986 ... -44.84 -59.25 -53.01
#     lapse_LWAS   (time) float64 1.669 5.556 2.773 4.948 ... 20.58 26.52 21.31
#     albedo_SWAS  (time) float64 0.0001474 0.02032 0.3478 ... 2.809 0.06988 0.0
#     albedo_SWCS  (time) float64 0.0006109 0.0781 0.7961 ... 4.02 0.1018 0.0
#     cloud_LW     (time) float64 0.9412 -0.4407 -0.05642 ... 4.302 3.422 3.349
#     cloud_SW     (time) float64 -0.0003012 0.009526 0.06149 ... 0.01552 0.0
#     cloud_NET    (time) float64 0.9409 -0.4312 0.005062 ... 4.288 3.438 3.349
#     atmos_conv   (time) float64 -3.395 -1.58 5.537 4.23 ... -19.04 -25.57 -23.99
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 1851-01-16 12:00:00 ... 2000-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -0.09596 0.1554 0.3427 ... 3.811 3.893 3.731
#     wv_LWAS      (time) float64 -1.023 0.07681 0.1325 ... 8.435 8.431 8.371
#     wv_LWCS      (time) float64 -1.178 0.1443 0.2831 1.179 ... 11.51 11.19 11.13
#     wv_SWAS      (time) float64 -0.2093 0.07637 0.04173 ... 1.415 1.297 1.269
#     wv_SWCS      (time) float64 -0.1266 0.06802 0.02855 ... 0.6442 0.6183 0.6311
#     wv_NETAS     (time) float64 -1.232 0.1532 0.1743 1.042 ... 9.85 9.728 9.639
#     wv_NETCS     (time) float64 -1.304 0.2123 0.3117 1.358 ... 12.15 11.81 11.76
#     planck_LWAS  (time) float64 0.3545 -0.5821 -1.27 ... -13.8 -14.13 -13.48
#     lapse_LWAS   (time) float64 -0.223 0.00661 -0.5111 ... -5.483 -5.551 -5.327
#     albedo_SWAS  (time) float64 0.02975 0.02803 0.01345 ... 0.1492 0.1649 0.153
#     albedo_SWCS  (time) float64 0.04065 0.01859 0.02218 ... 0.2104 0.2391 0.2239
#     cloud_LW     (time) float64 0.7665 1.064 0.5147 ... 0.5824 -0.2007 -0.3491
#     cloud_SW     (time) float64 1.216 0.2765 1.147 0.4331 ... 2.019 2.713 2.578
#     cloud_NET    (time) float64 1.982 1.341 1.661 0.9831 ... 2.601 2.512 2.229
#     atmos_conv   (time) float64 -1.384 -0.04796 -3.035 ... -1.593 -3.809 1.126
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# NorESM1-M
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 -1.21 3.982 0.4271 1.738 ... 17.78 22.27 22.04
#     wv_LWAS      (time) float64 -0.3215 0.1464 -0.7911 ... 3.09 1.984 1.001
#     wv_LWCS      (time) float64 -0.2971 0.2454 -0.9656 ... 3.874 2.485 1.163
#     wv_SWAS      (time) float64 -0.0001309 0.03752 -0.134 ... 0.3644 0.01234 0.0
#     wv_SWCS      (time) float64 -0.0001565 0.05148 -0.1445 ... 0.01515 0.0
#     wv_NETAS     (time) float64 -0.3216 0.184 -0.9251 ... 3.454 1.997 1.001
#     wv_NETCS     (time) float64 -0.2973 0.2969 -1.11 0.408 ... 4.273 2.501 1.163
#     planck_LWAS  (time) float64 2.851 -9.274 -0.9079 ... -45.41 -54.16 -51.74
#     lapse_LWAS   (time) float64 0.3414 3.581 1.952 1.938 ... 19.33 23.26 21.21
#     albedo_SWAS  (time) float64 -1.363e-06 0.0327 0.1731 ... 3.87 0.07482 0.0
#     albedo_SWCS  (time) float64 -7.028e-07 0.04795 0.1903 ... 5.449 0.09865 0.0
#     cloud_LW     (time) float64 1.237 1.122 0.2008 1.819 ... 9.283 8.791 8.867
#     cloud_SW     (time) float64 -0.0001692 -0.03832 0.06725 ... -0.03489 0.0
#     cloud_NET    (time) float64 1.237 1.084 0.268 1.236 ... 7.653 8.756 8.867
#     atmos_conv   (time) float64 18.7 6.932 -15.3 0.7501 ... 4.589 7.758 -29.01
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
# <xarray.Dataset>
# Dimensions:      (time: 1800)
# Coordinates:
#   * time         (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     dTs          (time) float64 0.1372 0.3509 0.4644 ... 3.319 3.263 3.145
#     wv_LWAS      (time) float64 -0.823 -0.1401 0.5292 ... 7.278 6.834 6.404
#     wv_LWCS      (time) float64 -0.8485 -0.05359 0.7519 ... 9.809 9.292 8.912
#     wv_SWAS      (time) float64 -0.1455 0.01593 0.00845 ... 1.203 1.1 1.052
#     wv_SWCS      (time) float64 -0.09319 0.01934 -0.05255 ... 0.5145 0.471
#     wv_NETAS     (time) float64 -0.9685 -0.1242 0.5377 ... 8.481 7.934 7.456
#     wv_NETCS     (time) float64 -0.9417 -0.03425 0.6994 ... 10.38 9.807 9.383
#     planck_LWAS  (time) float64 -0.4333 -1.235 -1.64 ... -11.92 -11.78 -11.32
#     lapse_LWAS   (time) float64 -0.2587 0.1446 -0.7778 ... -4.529 -3.74 -4.404
#     albedo_SWAS  (time) float64 -0.008091 0.08424 0.05209 ... 0.07768 0.142
#     albedo_SWCS  (time) float64 0.00476 0.1087 0.06458 ... 0.09094 0.08707 0.164
#     cloud_LW     (time) float64 0.2826 0.1004 1.237 -0.09634 ... 1.548 1.933 0.6
#     cloud_SW     (time) float64 2.304 3.363 0.5453 ... -2.205 -1.162 0.1665
#     cloud_NET    (time) float64 2.587 3.463 1.782 ... -0.6566 0.7702 0.7665
#     atmos_conv   (time) float64 -4.084 1.244 -3.573 ... -0.8827 0.5363 3.161
#     ml_conv      (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>

# %%
ocean_subarc
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1800)
# Coordinates:
#   * time     (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
# Data variables:
#     ml_conv  (time) float64 dask.array<chunksize=(1800,), meta=np.ndarray>
