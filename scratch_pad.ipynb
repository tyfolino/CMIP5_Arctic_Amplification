# %%
import xarray as xr

# %%
test = xr.open_dataset('/dx07/tylerj/CMIP5_output/CMIP5_feedbacks/bcc-csm1-1_albedo.nc',
                      use_cftime=True)

# %%
test2 = xr.open_dataset('/dx05/tylerj/d10/Arctic_Research/CMIP5_Arctic_Amplification/CAM5_feedbacks/bcc-csm1-1_abrupt4xCO2_albedo.nc',
                       use_cftime=True)

# %%
test.where(xr.ufuncs.isnan(test)).isel(time=-1).albedo_SWAS.plot()

# %%
test2.where(xr.ufuncs.isnan(test2)).isel(time=-1).FSNT.plot()

# %%
xr.ufuncs.isnan(test2.FSNT.isel(time=-1)).plot()

# %%
xr.ufuncs.isnan(test.albedo_SWAS.isel(time=-1)).plot()
